# %%
# !make clean
# !make
# Out:
# rm -rf *.o
# rm -rf *.d
# g++ -o City.o -c City.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o Human.o -c Human.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o main.o -c main.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o Position.o -c Position.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o RandMT.o -c RandMT.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o SimulationParams.o -c SimulationParams.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o World.o -c World.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -O2 City.o Human.o main.o Position.o RandMT.o SimulationParams.o World.o  -o exe

# %%
# !./replicationSimulation.sh 1 configToyEpidemicalContext configToyState
# Out:
# mts000M000000 0 configToyEpidemicalContext configToyState
# Nom de la commande :./exe
# Nom du fichier MT a utiliser :mts000M000000
# Num�ro de la replication :0
# config �pid�mie :configToyEpidemicalContext
# config g�ographique :configToyState
# ./mts-0000-0999/mts000M000000
# log file name : log-configToyEpidemicalContext-configToyState-MT-mts000M000000NumRepli0.txt
# 1000 1000
# 1000 1000
# La ville a pour coord X : 500 , coordY : 0, taille : 500 , nbHab : 10000
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# ***************STATISTICS******************
# Safe : 1771
# Contamined : 552
# Recovered : 96153
# Dead : 1524
#
# real	1m17,557s
# user	1m17,445s
# sys	0m0,088s

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st
import pandas as pd
import csv
from statistics import mean,variance
'''
Ce qu'on a comme résultats pour le moment :
- Les listes
- Taux de mortalité des gens contaminé
- Taux de mortalité par tranche d'age des gens contaminé
- Reffectif
- Taux d'incidence

On peut donc envisager beaucoup d'autres résultats.


'''

NB_REPLICATION = 30
NOM_EXPERIENCE = "configVaccin"
listDptConfig = ["configDpt75"]  

figureNouvCas = plt.figure()
axes = figureNouvCas.add_subplot()

pasFigure = 6 * NB_REPLICATION
compteurFigure = 0
for nbDpt in listDptConfig:

    compteurFigure = compteurFigure + pasFigure
    listResReplication = [[] for x in range(0,NB_REPLICATION)]


    for replication in listResReplication:

        listNumIteration = []
        listNbNouvCas = []
        listNbPersonneHosp = []
        listNbPersonneRea = []
        listNbNouvHosp = []
        listNbNouvRea = []
        listNbNouvMort = []
        nbCasCovidConnuTotal = 0
        listAgeMort = []
        listAgeNouvCasSymptomatique = []
        listReffectif = []
        listTauxIncidence = []
        
        temp = len(listDptConfig) * (listResReplication.index(replication)) + listDptConfig.index(nbDpt)
        stringFormat = f"{temp:04}"
        print(stringFormat)
        print("log-"+NOM_EXPERIENCE+"-"+nbDpt+ "-MT-mts000M00"+stringFormat+"NumRepli"+str(listResReplication.index(replication))+".txt")
        f = open("log-"+NOM_EXPERIENCE+"-"+nbDpt+ "-MT-mts000M00"+stringFormat+"NumRepli"+str(listResReplication.index(replication))+".txt", "r")
        fileLines = f.readlines()
        i = 0
        for line in fileLines:
            if("CompteurRand:" in line):
                listSplit = line.split(":")
                nbRandomGenere = (int(listSplit[1]))
            elif("NbHumainSimuDepart:" in line):
                listSplit = line.split(":")
                nbHumainSimuDepart = (int(listSplit[1]))
            elif("##" not in line):
                if(i == 0):
                    listNumIteration.append(int(line))
                    i = i + 1
                elif(i==1):
                    listNbNouvCas.append(int(line))
                    i = i + 1
                elif(i==2):
                    listNbPersonneHosp.append(int(line))
                    i = i + 1
                elif(i==3):
                    listNbPersonneRea.append(int(line))
                    i = i + 1
                elif(i==4):
                    listNbNouvHosp.append(int(line))
                    i = i + 1
                elif(i==5):
                    listNbNouvRea.append(int(line))
                    i = i + 1
                elif(i==6):
                    listNbNouvMort.append(int(line))
                    i = i + 1
                elif(i==7):
                    nbCasCovidConnuTotal = (int(line))
                    i = i + 1
                elif(i==8):
                    listReffectif.append(float(line))
                    i = i + 1
                elif(i==9):
                    listTauxIncidence.append(float(line))
                    i = i + 1
                elif("AgeC:" in line):
                    listSplit = line.split(":")
                    listAgeNouvCasSymptomatique.append(int(listSplit[1]))
                elif("AgeD:" in line):
                    listSplit = line.split(":")
                    listAgeMort.append(int(listSplit[1]))

            else:
                i = 0

        f.close()


        #label=str(ville)+ "-MT-"+stringFormat+"config"+NOM_EXPERIENCE+"NumRepli"+str(listResReplication.index(replication)+1) 
        axes.plot(listNumIteration, listNbNouvCas, label="test")
        """
        plt.figure((listResReplication.index(replication)*6)+compteurFigure)
        print("Courbe des nouveaux cas sur la réplication num : " +str(listResReplication.index(replication)))
        plt.plot(listNumIteration, listNbNouvCas)  # Matplotlib plot.
        plt.xlabel("Jour")
        plt.ylabel("Nouv Cas")
        plt.title(label="Courbe nouvCas"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("nouvCas"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        string = "nouvCas"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv"
        with open(string, "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listNbNouvCas)

        plt.figure((listResReplication.index(replication)*6+1)+compteurFigure)
        print("Courbe des nouvelles hospitalisation sur la réplication num : " +str(listResReplication.index(replication)))
        plt.plot(listNumIteration, listNbNouvHosp)
        plt.xlabel("Jour")
        plt.ylabel("Nouv Hosp")
        plt.title(label="Courbe nouvHosp"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("nouvHosp"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("nouvHosp"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listNbNouvHosp)

        plt.figure((listResReplication.index(replication)*6+2)+compteurFigure)
        print("Courbe des nouvelles réanimation sur la réplication num : " +str(listResReplication.index(replication)))
        plt.plot(listNumIteration, listNbNouvRea)
        plt.xlabel("Jour")
        plt.ylabel("Nouv Rea")
        plt.title(label="Courbe nouvRea"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("nouvRea"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("nouvRea"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listNbNouvRea)

        plt.figure((listResReplication.index(replication)*6+3)+compteurFigure)
        print("Courbe des nouveaux morts sur la réplication num : " +str(listResReplication.index(replication)))
        plt.plot(listNumIteration, listNbNouvMort)
        plt.xlabel("Jour")
        plt.ylabel("Nouv Mort")
        plt.title(label="Courbe nouvMort"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("nouvMort"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("nouvMort"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listNbNouvMort)

        print("Courbe de Reffectif sur la réplication num : " +str(listResReplication.index(replication)))
        plt.figure((listResReplication.index(replication)*6+4)+compteurFigure)
        plt.plot(listNumIteration, listReffectif)
        plt.xlabel("Jour")
        plt.ylabel("Reffectif")
        plt.title(label="Courbe Reffectif"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("Reffectif"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("Reffectif"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listReffectif)
            
        print("Courbe du taux d'incidence sur la réplication num : " +str(listResReplication.index(replication)))
        plt.figure((listResReplication.index(replication)*6+5)+compteurFigure)
        plt.plot(listNumIteration, listTauxIncidence)
        plt.xlabel("Jour")
        plt.ylabel("Taux Incidence")
        plt.title(label="Courbe Taux incidence"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("TauxIncidence"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("TauxIncidence"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listTauxIncidence)
        """
        nbMortTotal = sum(listNbNouvMort)
        try:
            tauxDeMortCasConnu = (nbMortTotal / nbCasCovidConnuTotal) * 100
        except:
            tauxDeMortCasConnu = 0
        tauxMortalitePopulationGobale = (nbMortTotal / nbHumainSimuDepart) * 100

        print("Le taux de mort de cas connu est de : " + str(tauxDeMortCasConnu) + "%")
        print("Le taux de mortalité du département sur l'ensemble de la population est de : " + str(tauxMortalitePopulationGobale) + "%")

        ## IL ME FAUT L'AGE DES GENS CONTAMINE AUSSI ... 


        nbAge0 = 0
        nbAge1 = 0
        nbAge2 = 0
        nbAge3 = 0
        nbAge4 = 0
        nbAge5 = 0
        nbAge6 = 0
        nbAge7 = 0

        for i in listAgeNouvCasSymptomatique:
            if i == 0:
                nbAge0 = nbAge0 + 1
            elif i == 1:
                nbAge1 = nbAge1 + 1
            elif i == 2:
                nbAge2 = nbAge2 + 1
            elif i == 3:
                nbAge3 = nbAge3 + 1
            elif i == 4:
                nbAge4 = nbAge4 + 1
            elif i == 5:
                nbAge5 = nbAge5 + 1
            elif i == 6:
                nbAge6 = nbAge6 + 1
            elif i == 7:
                nbAge7 = nbAge7 + 1


        nbAgeMort0 = 0
        nbAgeMort1 = 0
        nbAgeMort2 = 0
        nbAgeMort3 = 0
        nbAgeMort4 = 0
        nbAgeMort5 = 0
        nbAgeMort6 = 0
        nbAgeMort7 = 0

        for i in listAgeMort:
            if i == 0:
                nbAgeMort0 = nbAgeMort0 + 1
            elif i == 1:
                nbAgeMort1 = nbAgeMort1 + 1
            elif i == 2:
                nbAgeMort2 = nbAgeMort2 + 1
            elif i == 3:
                nbAgeMort3 = nbAgeMort3 + 1
            elif i == 4:
                nbAgeMort4 = nbAgeMort4 + 1
            elif i == 5:
                nbAgeMort5 = nbAgeMort5 + 1
            elif i == 6:
                nbAgeMort6 = nbAgeMort6 + 1
            elif i == 7:
                nbAgeMort7 = nbAgeMort7 + 1

        try :
            print("Le taux de mortalité pour les 0 - 15 ans est de : " + str( (nbAgeMort0/nbAge0) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 0 n'a été malade")
        try :
            print("Le taux de mortalité pour les 15 - 25 ans est de : " + str( (nbAgeMort1/nbAge1) * 100) + "%") 
        except ZeroDivisionError:
            print ("Aucun age 1 n'a été malade")
        try :
            print("Le taux de mortalité pour les 25 - 35 ans est de : " + str( (nbAgeMort2/nbAge2) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 2 n'a été malade")
        try:
            print("Le taux de mortalité pour les 35 - 45 ans est de : " + str( (nbAgeMort3/nbAge3) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 3 n'a été malade")
        try :
            print("Le taux de mortalité pour les 45 - 55 ans est de : " + str( (nbAgeMort4/nbAge4) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 4 n'a été malade")
        try:
            print("Le taux de mortalité pour les 55 - 65 ans est de : " + str( (nbAgeMort5/nbAge5) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 5 n'a été malade")
        try:
            print("Le taux de mortalité pour les 65 - 75 ans est de : " + str( (nbAgeMort6/nbAge6) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 6 n'a été malade")
        try:
            print("Le taux de mortalité pour les 75 + ans est de : " + str( (nbAgeMort7/nbAge7) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucune age 7 n'a été malade")

        print("############\n################")
        print(" replication = " + str(listResReplication.index(replication)))
        replication.append(listNumIteration)
        replication.append(listNbNouvCas)
        replication.append(listNbPersonneHosp)
        replication.append(listNbPersonneRea)
        replication.append(listNbNouvHosp)
        replication.append(listNbNouvMort)
        replication.append(listReffectif)
        replication.append(nbCasCovidConnuTotal)
        replication.append(tauxDeMortCasConnu)
        replication.append(tauxMortalitePopulationGobale)
        try :
            replication.append((nbAgeMort0/nbAge0) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort1/nbAge1) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort2/nbAge2) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort3/nbAge3) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort4/nbAge4) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort5/nbAge5) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort6/nbAge6) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort7/nbAge7) * 100)
        except ZeroDivisionError:
            replication.append(0)
            
        replication.append(int(nbRandomGenere))



    dataframeResultats = pd.DataFrame({"Champs":["nbCasCovidConnuTotal","tauxDeMortCasConnu","tauxMortalitePopulationGobale", "tauxDeMort0-15ans", "tauxDeMort15-25ans","tauxDeMort25-35ans","tauxDeMort35-45ans","tauxDeMort45-55ans","tauxDeMort55-65ans","tauxDeMort65-75ans","tauxDeMort75+ans","nbRandomGenere"]})
    numRepli = 1
    listResReplicationTruncated = []
    for replication in listResReplication:
        nomRepli = "R"+str(numRepli)
        dataframeResultats[nomRepli] = replication[-12:]
        listResReplicationTruncated.append(replication[-12:])
        numRepli = numRepli + 1

    
    if(NB_REPLICATION > 1):
        listMoyenne = [mean(list(map(float,list(r)))) for r in zip(*listResReplicationTruncated)]

        listVariance = [variance(list(map(float,list(r)))) for r in zip(*listResReplicationTruncated)]

        '''
        Confidence Intervals Using the t Distribution
        If we’re working with a small sample (n <30), we can use the t.interval() function from the scipy.stats library to calculate a confidence interval for a population mean.

        The following example shows how to calculate a confidence interval for the true population mean height (in inches) of a certain species of plant, using a sample of 15 plants:



        ###########
        Confidence Intervals Using the Normal Distribution
        If we’re working with larger samples (n≥30), we can assume that the sampling distribution of the sample mean is normally distributed (thanks to the Central Limit Theorem) and can instead use the norm.interval() function from the scipy.stats library.




        '''

        listIntervalle95 = [st.t.interval(alpha=0.95, df=len(r)-1, loc=np.mean(r), scale=st.sem(r)) for r in zip(*listResReplicationTruncated)]

        dataframeResultats["Moyenne"] = listMoyenne
        dataframeResultats["Variance"] = listVariance
        dataframeResultats["Intervalle95%"] = listIntervalle95

    print(dataframeResultats)

    dataframeResultats.to_csv("stats"+nbDpt + str(NOM_EXPERIENCE)+".csv", sep="|")
    dataframeResultats.to_html("stats"+nbDpt + str(NOM_EXPERIENCE)+".html",float_format='%.3f')
# Out:
# 0000
# log-configVaccin-configDpt75-MT-mts000M000000NumRepli0.txt
# Le taux de mort de cas connu est de : 0.8084298572698366%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8076943858082232%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03418431561446307%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0691532347229649%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2795451241739441%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4071346843653262%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.148103102149671%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7192130391834048%
# Le taux de mortalité pour les 75 + ans est de : 3.89969567863664%
# ############
# ################
#  replication = 0
# 0001
# log-configVaccin-configDpt75-MT-mts000M000001NumRepli1.txt
# Le taux de mort de cas connu est de : 0.8027667649844481%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8020142023059698%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0421800507708501%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08390305784493592%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2734265864516009%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4118757508151707%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.17324903975153%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7135539306812078%
# Le taux de mortalité pour les 75 + ans est de : 3.801942164069964%
# ############
# ################
#  replication = 1
# 0002
# log-configVaccin-configDpt75-MT-mts000M000002NumRepli2.txt
# Le taux de mort de cas connu est de : 0.8028011139743694%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8020603826596466%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03993796044978674%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07977019737080653%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.27832601452817024%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.3967920725562647%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.140574424769688%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7355966993039404%
# Le taux de mortalité pour les 75 + ans est de : 3.825274586542103%
# ############
# ################
#  replication = 2
# 0003
# log-configVaccin-configDpt75-MT-mts000M000003NumRepli3.txt
# Le taux de mort de cas connu est de : 0.7977841947297892%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7970267241088692%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03776934997780564%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0817184216670558%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2623909960808834%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.41444434729387075%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1049683220403026%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7221456457323967%
# Le taux de mortalité pour les 75 + ans est de : 3.8377289056339263%
# ############
# ################
#  replication = 3
# 0004
# log-configVaccin-configDpt75-MT-mts000M000004NumRepli4.txt
# Le taux de mort de cas connu est de : 0.8142471056926578%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8135131103715072%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.038773666476675704%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07153938283215575%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2634377507043042%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.42778434923393105%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1504506330980335%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.72551769655969%
# Le taux de mortalité pour les 75 + ans est de : 3.9437881199589166%
# ############
# ################
#  replication = 4
# 0005
# log-configVaccin-configDpt75-MT-mts000M000005NumRepli5.txt
# Le taux de mort de cas connu est de : 0.8081175063776248%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8073711233324852%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03824420093034873%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.06844048294825497%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.27393899746504213%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.42941417136702675%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.138305809880509%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7576681162472796%
# Le taux de mortalité pour les 75 + ans est de : 3.8282730838031616%
# ############
# ################
#  replication = 5
# 0006
# log-configVaccin-configDpt75-MT-mts000M000006NumRepli6.txt
# Le taux de mort de cas connu est de : 0.8027912562455883%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8020142023059698%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03036768255649168%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08438242113257281%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.26325826982476874%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.42050467557819393%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1546420499574395%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7238754068946784%
# Le taux de mortalité pour les 75 + ans est de : 3.8119187517024007%
# ############
# ################
#  replication = 6
# 0007
# log-configVaccin-configDpt75-MT-mts000M000007NumRepli7.txt
# Le taux de mort de cas connu est de : 0.8069544702587497%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8062166144905637%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03608119432632918%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.06954717952016466%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2704146233057067%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4432757588383794%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1445398737008867%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7260058412321786%
# Le taux de mortalité pour les 75 + ans est de : 3.852745160266582%
# ############
# ################
#  replication = 7
# 0008
# log-configVaccin-configDpt75-MT-mts000M000008NumRepli8.txt
# Le taux de mort de cas connu est de : 0.8001072356318121%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.799381922146389%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03456861092445788%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07814199286249425%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.27975831265878426%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.41264752411485534%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1360419416390621%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.6873447086600546%
# Le taux de mortalité pour les 75 + ans est de : 3.8463595218302298%
# ############
# ################
#  replication = 8
# 0009
# log-configVaccin-configDpt75-MT-mts000M000009NumRepli9.txt
# Le taux de mort de cas connu est de : 0.8030014217650224%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8022912844280309%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03650116881402266%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07632667818262162%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.26637815251455005%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.42248533572683256%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.146981214248332%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.6956211573274174%
# Le taux de mortalité pour les 75 + ans est de : 3.851500452031224%
# ############
# ################
#  replication = 9
# 0010
# log-configVaccin-configDpt75-MT-mts000M000010NumRepli10.txt
# Le taux de mort de cas connu est de : 0.8036047346347863%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8028454486721532%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.046598865317629516%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07570689814017392%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2824795258539948%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4139218038571899%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1287749601188184%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.727660312101464%
# Le taux de mortalité pour les 75 + ans est de : 3.8387323120102916%
# ############
# ################
#  replication = 10
# 0011
# log-configVaccin-configDpt75-MT-mts000M000011NumRepli11.txt
# Le taux de mort de cas connu est de : 0.8163140784595239%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8155450459332888%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.041720441846772906%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07852580881583081%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2592537089764724%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.43242222866990837%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.149175982736627%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7437618260442989%
# Le taux de mortalité pour les 75 + ans est de : 3.9021301483418487%
# ############
# ################
#  replication = 11
# 0012
# log-configVaccin-configDpt75-MT-mts000M000012NumRepli12.txt
# Le taux de mort de cas connu est de : 0.8102173923092213%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8094492392479438%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04152340445348215%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07556270096463022%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2709227066859987%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.40955822226570965%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1503013833810172%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.736089633359313%
# Le taux de mortalité pour les 75 + ans est de : 3.8778773927792587%
# ############
# ################
#  replication = 12
# 0013
# log-configVaccin-configDpt75-MT-mts000M000013NumRepli13.txt
# Le taux de mort de cas connu est de : 0.8039537161539091%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8032148915015681%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.041554043557958185%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.06555478248279689%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.28385142746309183%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4282670206448458%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1478752916536532%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7037959237517313%
# Le taux de mortalité pour les 75 + ans est de : 3.833895352514975%
# ############
# ################
#  replication = 13
# 0014
# log-configVaccin-configDpt75-MT-mts000M000014NumRepli14.txt
# Le taux de mort de cas connu est de : 0.8142546329914566%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8135131103715072%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03348714054864397%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0872445984738226%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2740860070703003%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.39882069525757025%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1918587557332705%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7380961200492249%
# Le taux de mortalité pour les 75 + ans est de : 3.881221857125471%
# ############
# ################
#  replication = 14
# 0015
# log-configVaccin-configDpt75-MT-mts000M000015NumRepli15.txt
# Le taux de mort de cas connu est de : 0.8066506732489287%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8058933520148257%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03300342847380498%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08619099925434763%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2589426632290225%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4239998601814146%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1609063319484958%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7370411055842867%
# Le taux de mortalité pour les 75 + ans est de : 3.832555783896448%
# ############
# ################
#  replication = 15
# 0016
# log-configVaccin-configDpt75-MT-mts000M000016NumRepli16.txt
# Le taux de mort de cas connu est de : 0.8009732971921559%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8002131685125724%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03618719284660911%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07796111588879691%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2650495665024997%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.39596202682188003%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1628931371685314%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7391914596741234%
# Le taux de mortalité pour les 75 + ans est de : 3.7998930429286792%
# ############
# ################
#  replication = 16
# 0017
# log-configVaccin-configDpt75-MT-mts000M000017NumRepli17.txt
# Le taux de mort de cas connu est de : 0.8080272109472388%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8073249429788083%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03452395729890764%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07126550628706713%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2453905364281878%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4324037814408112%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1895818139839995%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7236125865717982%
# Le taux de mortalité pour les 75 + ans est de : 3.845609928559237%
# ############
# ################
#  replication = 17
# 0018
# log-configVaccin-configDpt75-MT-mts000M000018NumRepli18.txt
# Le taux de mort de cas connu est de : 0.8077742318402183%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8070016805030703%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04124016169255849%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07945616668138077%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2679079736110646%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4324180368080961%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1521896376367262%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7636829996654373%
# Le taux de mortalité pour les 75 + ans est de : 3.8073182028717%
# ############
# ################
#  replication = 18
# 0019
# log-configVaccin-configDpt75-MT-mts000M000019NumRepli19.txt
# Le taux de mort de cas connu est de : 0.8110303080167938%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.810280485614127%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04245474090923254%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08325758367990475%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2719421450557332%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.41340295909486513%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1386136801999802%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7438448887162492%
# Le taux de mortalité pour les 75 + ans est de : 3.8681171904489977%
# ############
# ################
#  replication = 19
# 0020
# log-configVaccin-configDpt75-MT-mts000M000020NumRepli20.txt
# Le taux de mort de cas connu est de : 0.8033188499583989%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.802568366550092%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03968145903278389%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07394785068964409%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2548634580201879%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.40410037895325074%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1456099638692243%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.753389208445132%
# Le taux de mortalité pour les 75 + ans est de : 3.831685088229591%
# ############
# ################
#  replication = 20
# 0021
# log-configVaccin-configDpt75-MT-mts000M000021NumRepli21.txt
# Le taux de mort de cas connu est de : 0.7976696232412742%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7969343634015155%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03381503564182493%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07063819198336792%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2787719108377712%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.42992381805960117%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1481990651635963%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7115812320248898%
# Le taux de mortalité pour les 75 + ans est de : 3.765020676234493%
# ############
# ################
#  replication = 21
# 0022
# log-configVaccin-configDpt75-MT-mts000M000022NumRepli22.txt
# Le taux de mort de cas connu est de : 0.8212478881767946%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8204863437767125%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03216493247301827%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07810707110561768%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.27112483287463085%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.43273799713144506%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.2169521880183791%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7151987612682176%
# Le taux de mortalité pour les 75 + ans est de : 3.9120648332255694%
# ############
# ################
#  replication = 22
# 0023
# log-configVaccin-configDpt75-MT-mts000M000023NumRepli23.txt
# Le taux de mort de cas connu est de : 0.8038846799206794%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8031225307942144%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0349582443192853%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0726875519555361%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2746003949476508%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4169917126395366%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1742722626266326%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7630826682529452%
# Le taux de mortalité pour les 75 + ans est de : 3.750498090249094%
# ############
# ################
#  replication = 23
# 0024
# log-configVaccin-configDpt75-MT-mts000M000024NumRepli24.txt
# Le taux de mort de cas connu est de : 0.813707862052389%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8129589461273848%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03719229189750425%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07284464370517639%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.27278478657288524%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4303260736250066%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1707567399153271%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.782295861112945%
# Le taux de mortalité pour les 75 + ans est de : 3.8261750918535413%
# ############
# ################
#  replication = 24
# 0025
# log-configVaccin-configDpt75-MT-mts000M000025NumRepli25.txt
# Le taux de mort de cas connu est de : 0.8005783392714183%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7998437256831575%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.039200922191991366%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07905994911268249%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.25808427516041565%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.3895890046211142%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1492483146190984%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7342018092790523%
# Le taux de mortalité pour les 75 + ans est de : 3.833635775411216%
# ############
# ################
#  replication = 25
# 0026
# log-configVaccin-configDpt75-MT-mts000M000026NumRepli26.txt
# Le taux de mort de cas connu est de : 0.8028137308512423%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8020603826596466%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03650655564531163%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07227406324783579%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2676563872716173%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4243672069716471%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1451138868479058%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.6906149828586985%
# Le taux de mortalité pour les 75 + ans est de : 3.8617619471133984%
# ############
# ################
#  replication = 26
# 0027
# log-configVaccin-configDpt75-MT-mts000M000027NumRepli27.txt
# Le taux de mort de cas connu est de : 0.8090587960125323%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8082947304060223%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03925180616603126%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08150613705076266%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.27521227469089826%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4208383183258821%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1686394326054066%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7189356092432626%
# Le taux de mortalité pour les 75 + ans est de : 3.8565372057891913%
# ############
# ################
#  replication = 27
# 0028
# log-configVaccin-configDpt75-MT-mts000M000028NumRepli28.txt
# Le taux de mort de cas connu est de : 0.8017875434035803%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8010444148787557%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04423628384172723%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0839701403787897%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2535538494761376%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4186074140334816%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1794421179956838%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7110313235112047%
# Le taux de mortalité pour les 75 + ans est de : 3.7934124155125732%
# ############
# ################
#  replication = 28
# 0029
# log-configVaccin-configDpt75-MT-mts000M000029NumRepli29.txt
# Le taux de mort de cas connu est de : 0.8045459504135287%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8037690557456904%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04076989085317792%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08789285900620868%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.293441015373028%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4201695359608494%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1714727085478887%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.6963086901737208%
# Le taux de mortalité pour les 75 + ans est de : 3.7948328784982173%
# ############
# ################
#  replication = 29
#                            Champs            R1            R2            R3  \
# 0            nbCasCovidConnuTotal  2.163453e+06  2.163393e+06  2.163425e+06
# 1              tauxDeMortCasConnu  8.084299e-01  8.027668e-01  8.028011e-01
# 2   tauxMortalitePopulationGobale  8.076944e-01  8.020142e-01  8.020604e-01
# 3               tauxDeMort0-15ans  0.000000e+00  0.000000e+00  0.000000e+00
# 4              tauxDeMort15-25ans  3.418432e-02  4.218005e-02  3.993796e-02
# 5              tauxDeMort25-35ans  6.915323e-02  8.390306e-02  7.977020e-02
# 6              tauxDeMort35-45ans  2.795451e-01  2.734266e-01  2.783260e-01
# 7              tauxDeMort45-55ans  4.071347e-01  4.118758e-01  3.967921e-01
# 8              tauxDeMort55-65ans  1.148103e+00  1.173249e+00  1.140574e+00
# 9              tauxDeMort65-75ans  1.719213e+00  1.713554e+00  1.735597e+00
# 10               tauxDeMort75+ans  3.899696e+00  3.801942e+00  3.825275e+00
# 11                 nbRandomGenere  3.583846e+09  3.583998e+09  3.584016e+09
#
#               R4            R5            R6            R7            R8  \
# 0   2.163367e+06  2.163471e+06  2.163423e+06  2.163327e+06  2.163443e+06
# 1   7.977842e-01  8.142471e-01  8.081175e-01  8.027913e-01  8.069545e-01
# 2   7.970267e-01  8.135131e-01  8.073711e-01  8.020142e-01  8.062166e-01
# 3   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 4   3.776935e-02  3.877367e-02  3.824420e-02  3.036768e-02  3.608119e-02
# 5   8.171842e-02  7.153938e-02  6.844048e-02  8.438242e-02  6.954718e-02
# 6   2.623910e-01  2.634378e-01  2.739390e-01  2.632583e-01  2.704146e-01
# 7   4.144443e-01  4.277843e-01  4.294142e-01  4.205047e-01  4.432758e-01
# 8   1.104968e+00  1.150451e+00  1.138306e+00  1.154642e+00  1.144540e+00
# 9   1.722146e+00  1.725518e+00  1.757668e+00  1.723875e+00  1.726006e+00
# 10  3.837729e+00  3.943788e+00  3.828273e+00  3.811919e+00  3.852745e+00
# 11  3.584147e+09  3.583677e+09  3.583820e+09  3.584015e+09  3.583870e+09
#
#               R9  ...           R24           R25           R26           R27  \
# 0   2.163460e+06  ...  2.163370e+06  2.163430e+06  2.163436e+06  2.163391e+06
# 1   8.001072e-01  ...  8.038847e-01  8.137079e-01  8.005783e-01  8.028137e-01
# 2   7.993819e-01  ...  8.031225e-01  8.129589e-01  7.998437e-01  8.020604e-01
# 3   0.000000e+00  ...  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 4   3.456861e-02  ...  3.495824e-02  3.719229e-02  3.920092e-02  3.650656e-02
# 5   7.814199e-02  ...  7.268755e-02  7.284464e-02  7.905995e-02  7.227406e-02
# 6   2.797583e-01  ...  2.746004e-01  2.727848e-01  2.580843e-01  2.676564e-01
# 7   4.126475e-01  ...  4.169917e-01  4.303261e-01  3.895890e-01  4.243672e-01
# 8   1.136042e+00  ...  1.174272e+00  1.170757e+00  1.149248e+00  1.145114e+00
# 9   1.687345e+00  ...  1.763083e+00  1.782296e+00  1.734202e+00  1.690615e+00
# 10  3.846360e+00  ...  3.750498e+00  3.826175e+00  3.833636e+00  3.861762e+00
# 11  3.584088e+09  ...  3.583955e+09  3.583670e+09  3.584057e+09  3.584005e+09
#
#              R28           R29           R30       Moyenne      Variance  \
# 0   2.163378e+06  2.163416e+06  2.163332e+06  2.163412e+06  2.314838e+03
# 1   8.090588e-01  8.017875e-01  8.045460e-01  8.062805e-01  3.177118e-05
# 2   8.082947e-01  8.010444e-01  8.037691e-01  8.055316e-01  3.174186e-05
# 3   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 4   3.925181e-02  4.423628e-02  4.076989e-02  3.795597e-02  1.490914e-05
# 5   8.150614e-02  8.397014e-02  8.789286e-02  7.721926e-02  3.652024e-05
# 6   2.752123e-01  2.535538e-01  2.934410e-01  2.696931e-01  1.038556e-04
# 7   4.208383e-01  4.186074e-01  4.201695e-01  4.185062e-01  1.663418e-04
# 8   1.168639e+00  1.179442e+00  1.171473e+00  1.155991e+00  4.619111e-04
# 9   1.718936e+00  1.711031e+00  1.696309e+00  1.727999e+00  5.105602e-04
# 10  3.856537e+00  3.793412e+00  3.794833e+00  3.840407e+00  1.790808e-03
# 11  3.583812e+09  3.584038e+09  3.583964e+09  3.583902e+09  2.790259e+10
#
#                                   Intervalle95%
# 0       (2163393.7343991655, 2163429.665600835)
# 1       (0.8041757436948683, 0.808385220706863)
# 2       (0.803427839028621, 0.8076353727934263)
# 3                                    (nan, nan)
# 4   (0.03651415743663048, 0.039397775886668644)
# 5    (0.07496268833848187, 0.07947582286074482)
# 6    (0.26588777650456225, 0.27349850841606066)
# 7     (0.41369027390334023, 0.4233221771135903)
# 8      (1.1479658468222906, 1.1640164242447568)
# 9       (1.7195613136740544, 1.736435969226628)
# 10       (3.82460494284326, 3.8562084996946697)
# 11       (3583839261.646056, 3583964009.687277)
#
# [12 rows x 34 columns]
# /tmp/ipykernel_132100/4101639869.py:360: DeprecationWarning: Use of keyword argument 'alpha' for method 'interval' is deprecated and wil be removed in SciPy 1.11.0. Use first positional argument or keyword argument 'confidence' instead.
#   listIntervalle95 = [st.t.interval(alpha=0.95, df=len(r)-1, loc=np.mean(r), scale=st.sem(r)) for r in zip(*listResReplicationTruncated)]
# /usr/lib/python3/dist-packages/scipy/stats/_distn_infrastructure.py:2351: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /usr/lib/python3/dist-packages/scipy/stats/_distn_infrastructure.py:2352: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
import matplotlib.pyplot as plt
plt.plot([44,221,588,917,1990],[70000,161000,264000,330000,492000])

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

x = np.array([44,221,588,917,1990]).reshape(-1,1)
y = np.array([70000,161000,264000,330000,492000])

model = LinearRegression()
model.fit(np.log(x),y)

x_pred = np.array([50,100,220,500,1000,1500,3000,5000,8000,12000]).reshape(-1,1)
y_pred = model.predict(np.log(x_pred))
print(y_pred)

plt.plot([44,221,588,917,1990],[70000,161000,264000,330000,492000],color='r')
plt.plot([50,100,220,500,1000,1500,3000,5000,8000,12000],y_pred)
# Out:
# [ 43885.06248518 116924.96278337 200008.1067469  286518.35933351
#  359558.2596317  402283.86236256 475323.76266075 529151.65618184
#  578677.96052628 621403.56325713]
