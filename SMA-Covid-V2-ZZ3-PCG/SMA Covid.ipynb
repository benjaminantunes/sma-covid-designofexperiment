# %%
# !make clean
# !make
# Out:
# rm -rf *.o
# rm -rf *.d
# g++ -o City.o -c City.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o Human.o -c Human.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o main.o -c main.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o Position.o -c Position.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o SimulationParams.o -c SimulationParams.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o World.o -c World.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -O2 City.o Human.o main.o Position.o SimulationParams.o World.o  -o exe

# %%
# !./replicationSimulation.sh 1 configToyEpidemicalContext configToyState
# Out:
# mts000M000000 0 configToyEpidemicalContext configToyState
# Nom de la commande :./exe
# Nom du fichier MT a utiliser :mts000M000000
# Num�ro de la replication :0
# config �pid�mie :configToyEpidemicalContext
# config g�ographique :configToyState
# log file name : log-configToyEpidemicalContext-configToyState-PCG-NumRepli0.txt
# La ville a pour coord X : 500 , coordY : 0, taille : 500 , nbHab : 10000
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# ***************STATISTICS******************
# Safe : 1384
# Contamined : 523
# Recovered : 96572
# Dead : 1521
#
# real	0m23,558s
# user	0m23,456s
# sys	0m0,088s

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st
import pandas as pd
import csv
from statistics import mean,variance
'''
Ce qu'on a comme résultats pour le moment :
- Les listes
- Taux de mortalité des gens contaminé
- Taux de mortalité par tranche d'age des gens contaminé
- Reffectif
- Taux d'incidence

On peut donc envisager beaucoup d'autres résultats.


'''

NB_REPLICATION = 30
NOM_EXPERIENCE = "configVaccin"
listDptConfig = ["configDpt75"]  

figureNouvCas = plt.figure()
axes = figureNouvCas.add_subplot()

pasFigure = 6 * NB_REPLICATION
compteurFigure = 0
for nbDpt in listDptConfig:

    compteurFigure = compteurFigure + pasFigure
    listResReplication = [[] for x in range(0,NB_REPLICATION)]


    for replication in listResReplication:

        listNumIteration = []
        listNbNouvCas = []
        listNbPersonneHosp = []
        listNbPersonneRea = []
        listNbNouvHosp = []
        listNbNouvRea = []
        listNbNouvMort = []
        nbCasCovidConnuTotal = 0
        listAgeMort = []
        listAgeNouvCasSymptomatique = []
        listReffectif = []
        listTauxIncidence = []
        
        temp = len(listDptConfig) * (listResReplication.index(replication)) + listDptConfig.index(nbDpt)
        stringFormat = f"{temp:04}"
        print(stringFormat)
        print("log-"+NOM_EXPERIENCE+"-"+nbDpt+ "-PCG-NumRepli"+str(listResReplication.index(replication))+".txt")
        f = open("log-"+NOM_EXPERIENCE+"-"+nbDpt+ "-PCG-NumRepli"+str(listResReplication.index(replication))+".txt", "r")
        fileLines = f.readlines()
        i = 0
        #### nbRandomGenere is only available with MT, so I set it to 0 here.
        nbRandomGenere = 0
        for line in fileLines:
            if("CompteurRand:" in line):
                listSplit = line.split(":")
                nbRandomGenere = (int(listSplit[1]))
            elif("NbHumainSimuDepart:" in line):
                listSplit = line.split(":")
                nbHumainSimuDepart = (int(listSplit[1]))
            elif("##" not in line):
                if(i == 0):
                    listNumIteration.append(int(line))
                    i = i + 1
                elif(i==1):
                    listNbNouvCas.append(int(line))
                    i = i + 1
                elif(i==2):
                    listNbPersonneHosp.append(int(line))
                    i = i + 1
                elif(i==3):
                    listNbPersonneRea.append(int(line))
                    i = i + 1
                elif(i==4):
                    listNbNouvHosp.append(int(line))
                    i = i + 1
                elif(i==5):
                    listNbNouvRea.append(int(line))
                    i = i + 1
                elif(i==6):
                    listNbNouvMort.append(int(line))
                    i = i + 1
                elif(i==7):
                    nbCasCovidConnuTotal = (int(line))
                    i = i + 1
                elif(i==8):
                    listReffectif.append(float(line))
                    i = i + 1
                elif(i==9):
                    listTauxIncidence.append(float(line))
                    i = i + 1
                elif("AgeC:" in line):
                    listSplit = line.split(":")
                    listAgeNouvCasSymptomatique.append(int(listSplit[1]))
                elif("AgeD:" in line):
                    listSplit = line.split(":")
                    listAgeMort.append(int(listSplit[1]))

            else:
                i = 0

        f.close()


        #label=str(ville)+ "-MT-"+stringFormat+"config"+NOM_EXPERIENCE+"NumRepli"+str(listResReplication.index(replication)+1) 
        axes.plot(listNumIteration, listNbNouvCas, label="test")
        """
        plt.figure((listResReplication.index(replication)*6)+compteurFigure)
        print("Courbe des nouveaux cas sur la réplication num : " +str(listResReplication.index(replication)))
        plt.plot(listNumIteration, listNbNouvCas)  # Matplotlib plot.
        plt.xlabel("Jour")
        plt.ylabel("Nouv Cas")
        plt.title(label="Courbe nouvCas"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("nouvCas"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        string = "nouvCas"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv"
        with open(string, "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listNbNouvCas)

        plt.figure((listResReplication.index(replication)*6+1)+compteurFigure)
        print("Courbe des nouvelles hospitalisation sur la réplication num : " +str(listResReplication.index(replication)))
        plt.plot(listNumIteration, listNbNouvHosp)
        plt.xlabel("Jour")
        plt.ylabel("Nouv Hosp")
        plt.title(label="Courbe nouvHosp"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("nouvHosp"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("nouvHosp"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listNbNouvHosp)

        plt.figure((listResReplication.index(replication)*6+2)+compteurFigure)
        print("Courbe des nouvelles réanimation sur la réplication num : " +str(listResReplication.index(replication)))
        plt.plot(listNumIteration, listNbNouvRea)
        plt.xlabel("Jour")
        plt.ylabel("Nouv Rea")
        plt.title(label="Courbe nouvRea"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("nouvRea"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("nouvRea"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listNbNouvRea)

        plt.figure((listResReplication.index(replication)*6+3)+compteurFigure)
        print("Courbe des nouveaux morts sur la réplication num : " +str(listResReplication.index(replication)))
        plt.plot(listNumIteration, listNbNouvMort)
        plt.xlabel("Jour")
        plt.ylabel("Nouv Mort")
        plt.title(label="Courbe nouvMort"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("nouvMort"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("nouvMort"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listNbNouvMort)

        print("Courbe de Reffectif sur la réplication num : " +str(listResReplication.index(replication)))
        plt.figure((listResReplication.index(replication)*6+4)+compteurFigure)
        plt.plot(listNumIteration, listReffectif)
        plt.xlabel("Jour")
        plt.ylabel("Reffectif")
        plt.title(label="Courbe Reffectif"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("Reffectif"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("Reffectif"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listReffectif)
            
        print("Courbe du taux d'incidence sur la réplication num : " +str(listResReplication.index(replication)))
        plt.figure((listResReplication.index(replication)*6+5)+compteurFigure)
        plt.plot(listNumIteration, listTauxIncidence)
        plt.xlabel("Jour")
        plt.ylabel("Taux Incidence")
        plt.title(label="Courbe Taux incidence"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("TauxIncidence"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("TauxIncidence"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listTauxIncidence)
        """
        nbMortTotal = sum(listNbNouvMort)
        try:
            tauxDeMortCasConnu = (nbMortTotal / nbCasCovidConnuTotal) * 100
        except:
            tauxDeMortCasConnu = 0
        tauxMortalitePopulationGobale = (nbMortTotal / nbHumainSimuDepart) * 100

        print("Le taux de mort de cas connu est de : " + str(tauxDeMortCasConnu) + "%")
        print("Le taux de mortalité du département sur l'ensemble de la population est de : " + str(tauxMortalitePopulationGobale) + "%")

        ## IL ME FAUT L'AGE DES GENS CONTAMINE AUSSI ... 


        nbAge0 = 0
        nbAge1 = 0
        nbAge2 = 0
        nbAge3 = 0
        nbAge4 = 0
        nbAge5 = 0
        nbAge6 = 0
        nbAge7 = 0

        for i in listAgeNouvCasSymptomatique:
            if i == 0:
                nbAge0 = nbAge0 + 1
            elif i == 1:
                nbAge1 = nbAge1 + 1
            elif i == 2:
                nbAge2 = nbAge2 + 1
            elif i == 3:
                nbAge3 = nbAge3 + 1
            elif i == 4:
                nbAge4 = nbAge4 + 1
            elif i == 5:
                nbAge5 = nbAge5 + 1
            elif i == 6:
                nbAge6 = nbAge6 + 1
            elif i == 7:
                nbAge7 = nbAge7 + 1


        nbAgeMort0 = 0
        nbAgeMort1 = 0
        nbAgeMort2 = 0
        nbAgeMort3 = 0
        nbAgeMort4 = 0
        nbAgeMort5 = 0
        nbAgeMort6 = 0
        nbAgeMort7 = 0

        for i in listAgeMort:
            if i == 0:
                nbAgeMort0 = nbAgeMort0 + 1
            elif i == 1:
                nbAgeMort1 = nbAgeMort1 + 1
            elif i == 2:
                nbAgeMort2 = nbAgeMort2 + 1
            elif i == 3:
                nbAgeMort3 = nbAgeMort3 + 1
            elif i == 4:
                nbAgeMort4 = nbAgeMort4 + 1
            elif i == 5:
                nbAgeMort5 = nbAgeMort5 + 1
            elif i == 6:
                nbAgeMort6 = nbAgeMort6 + 1
            elif i == 7:
                nbAgeMort7 = nbAgeMort7 + 1

        try :
            print("Le taux de mortalité pour les 0 - 15 ans est de : " + str( (nbAgeMort0/nbAge0) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 0 n'a été malade")
        try :
            print("Le taux de mortalité pour les 15 - 25 ans est de : " + str( (nbAgeMort1/nbAge1) * 100) + "%") 
        except ZeroDivisionError:
            print ("Aucun age 1 n'a été malade")
        try :
            print("Le taux de mortalité pour les 25 - 35 ans est de : " + str( (nbAgeMort2/nbAge2) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 2 n'a été malade")
        try:
            print("Le taux de mortalité pour les 35 - 45 ans est de : " + str( (nbAgeMort3/nbAge3) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 3 n'a été malade")
        try :
            print("Le taux de mortalité pour les 45 - 55 ans est de : " + str( (nbAgeMort4/nbAge4) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 4 n'a été malade")
        try:
            print("Le taux de mortalité pour les 55 - 65 ans est de : " + str( (nbAgeMort5/nbAge5) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 5 n'a été malade")
        try:
            print("Le taux de mortalité pour les 65 - 75 ans est de : " + str( (nbAgeMort6/nbAge6) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 6 n'a été malade")
        try:
            print("Le taux de mortalité pour les 75 + ans est de : " + str( (nbAgeMort7/nbAge7) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucune age 7 n'a été malade")

        print("############\n################")
        print(" replication = " + str(listResReplication.index(replication)))
        replication.append(listNumIteration)
        replication.append(listNbNouvCas)
        replication.append(listNbPersonneHosp)
        replication.append(listNbPersonneRea)
        replication.append(listNbNouvHosp)
        replication.append(listNbNouvMort)
        replication.append(listReffectif)
        replication.append(nbCasCovidConnuTotal)
        replication.append(tauxDeMortCasConnu)
        replication.append(tauxMortalitePopulationGobale)
        try :
            replication.append((nbAgeMort0/nbAge0) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort1/nbAge1) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort2/nbAge2) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort3/nbAge3) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort4/nbAge4) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort5/nbAge5) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort6/nbAge6) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort7/nbAge7) * 100)
        except ZeroDivisionError:
            replication.append(0)
            
        replication.append(int(nbRandomGenere))



    dataframeResultats = pd.DataFrame({"Champs":["nbCasCovidConnuTotal","tauxDeMortCasConnu","tauxMortalitePopulationGobale", "tauxDeMort0-15ans", "tauxDeMort15-25ans","tauxDeMort25-35ans","tauxDeMort35-45ans","tauxDeMort45-55ans","tauxDeMort55-65ans","tauxDeMort65-75ans","tauxDeMort75+ans","nbRandomGenere"]})
    numRepli = 1
    listResReplicationTruncated = []
    for replication in listResReplication:
        nomRepli = "R"+str(numRepli)
        dataframeResultats[nomRepli] = replication[-12:]
        listResReplicationTruncated.append(replication[-12:])
        numRepli = numRepli + 1

    
    if(NB_REPLICATION > 1):
        listMoyenne = [mean(list(map(float,list(r)))) for r in zip(*listResReplicationTruncated)]

        listVariance = [variance(list(map(float,list(r)))) for r in zip(*listResReplicationTruncated)]

        '''
        Confidence Intervals Using the t Distribution
        If we’re working with a small sample (n <30), we can use the t.interval() function from the scipy.stats library to calculate a confidence interval for a population mean.

        The following example shows how to calculate a confidence interval for the true population mean height (in inches) of a certain species of plant, using a sample of 15 plants:



        ###########
        Confidence Intervals Using the Normal Distribution
        If we’re working with larger samples (n≥30), we can assume that the sampling distribution of the sample mean is normally distributed (thanks to the Central Limit Theorem) and can instead use the norm.interval() function from the scipy.stats library.




        '''

        listIntervalle95 = [st.t.interval(alpha=0.95, df=len(r)-1, loc=np.mean(r), scale=st.sem(r)) for r in zip(*listResReplicationTruncated)]

        dataframeResultats["Moyenne"] = listMoyenne
        dataframeResultats["Variance"] = listVariance
        dataframeResultats["Intervalle95%"] = listIntervalle95

    print(dataframeResultats)

    dataframeResultats.to_csv("stats"+nbDpt + str(NOM_EXPERIENCE)+".csv", sep="|")
    dataframeResultats.to_html("stats"+nbDpt + str(NOM_EXPERIENCE)+".html",float_format='%.3f')
# Out:
# 0000
# log-configVaccin-configDpt75-PCG-NumRepli0.txt
# Le taux de mort de cas connu est de : 0.8124245112209895%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8116658962244329%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03721839053722421%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08217655067956785%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.24837992791379537%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4169382020503549%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1615431092883168%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7403739557962323%
# Le taux de mortalité pour les 75 + ans est de : 3.907935163139008%
# ############
# ################
#  replication = 0
# 0001
# log-configVaccin-configDpt75-PCG-NumRepli1.txt
# Le taux de mort de cas connu est de : 0.8042295661949019%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8034919736236292%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.039972989125794604%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07153507026914066%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.25568001552742864%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.422080985041981%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1567822351038213%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7223714108655235%
# Le taux de mortalité pour les 75 + ans est de : 3.848403607116744%
# ############
# ################
#  replication = 1
# 0002
# log-configVaccin-configDpt75-PCG-NumRepli2.txt
# Le taux de mort de cas connu est de : 0.8025219212084513%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8017833005375854%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03884158846560189%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07658472235030894%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2589909800979986%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.40242361629798196%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1616899175882642%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.732920536635707%
# Le taux de mortalité pour les 75 + ans est de : 3.827872365293957%
# ############
# ################
#  replication = 2
# 0003
# log-configVaccin-configDpt75-PCG-NumRepli3.txt
# Le taux de mort de cas connu est de : 0.8056445503085246%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.804877384233935%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03194029501926156%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07395736197305379%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.27498425733757115%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4052422529789505%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.149931547324106%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7378173311383693%
# Le taux de mortalité pour les 75 + ans est de : 3.8373230772211624%
# ############
# ################
#  replication = 3
# 0004
# log-configVaccin-configDpt75-PCG-NumRepli4.txt
# Le taux de mort de cas connu est de : 0.8062268334588295%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.805477728831734%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04387003598895872%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.06862784444355259%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.26645132239493596%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4368761422747083%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1538941175607573%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.724972588286406%
# Le taux de mortalité pour les 75 + ans est de : 3.835227272727273%
# ############
# ################
#  replication = 4
# 0005
# log-configVaccin-configDpt75-PCG-NumRepli5.txt
# Le taux de mort de cas connu est de : 0.8080608250429522%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8073249429788083%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04710168904321288%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07396687570348931%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.25541551426503073%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4222904782799473%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.156993213825132%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7161942350405825%
# Le taux de mortalité pour les 75 + ans est de : 3.880020810136676%
# ############
# ################
#  replication = 5
# 0006
# log-configVaccin-configDpt75-PCG-NumRepli6.txt
# Le taux de mort de cas connu est de : 0.8030444783007425%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8022912844280309%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04108941211129804%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07608328100091784%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.27169856387901953%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.42449863127303905%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1423649923952282%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7309619031058783%
# Le taux de mortalité pour les 75 + ans est de : 3.8131906060561866%
# ############
# ################
#  replication = 6
# 0007
# log-configVaccin-configDpt75-PCG-NumRepli7.txt
# Le taux de mort de cas connu est de : 0.798445448805475%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7977194294140221%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.041375043501798076%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07719679150835294%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2832426032842654%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.43674244814121577%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.0999006091813643%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.6919110538188848%
# Le taux de mortalité pour les 75 + ans est de : 3.8260016607343164%
# ############
# ################
#  replication = 7
# 0008
# log-configVaccin-configDpt75-PCG-NumRepli8.txt
# Le taux de mort de cas connu est de : 0.8068075979967322%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8060780734295331%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.043094077087927445%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07857073783966734%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2830793069026654%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.43320115054874475%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1372852613728526%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.751074588606682%
# Le taux de mortalité pour les 75 + ans est de : 3.7929092885989437%
# ############
# ################
#  replication = 8
# 0009
# log-configVaccin-configDpt75-PCG-NumRepli9.txt
# Le taux de mort de cas connu est de : 0.796465781324611%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7956874938522405%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.038091832411485074%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.06948377172371967%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.25585177007653176%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4158819287399617%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1431596049299217%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7276502551600175%
# Le taux de mortalité pour les 75 + ans est de : 3.780228734394552%
# ############
# ################
#  replication = 9
# 0010
# log-configVaccin-configDpt75-PCG-NumRepli10.txt
# Le taux de mort de cas connu est de : 0.8036804654847737%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8029378093795069%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.036201560949025866%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.06510416666666666%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.29490946056144507%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.40743177967881494%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1326718441760353%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.713131947082432%
# Le taux de mortalité pour les 75 + ans est de : 3.86192804495366%
# ############
# ################
#  replication = 10
# 0011
# log-configVaccin-configDpt75-PCG-NumRepli11.txt
# Le taux de mort de cas connu est de : 0.800688179518339%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7999360863905113%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.037717214214334875%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07900390585636606%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2745308390884235%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4088136019623053%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1603812681309573%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7261985996865217%
# Le taux de mortalité pour les 75 + ans est de : 3.7838757504314224%
# ############
# ################
#  replication = 11
# 0012
# log-configVaccin-configDpt75-PCG-NumRepli12.txt
# Le taux de mort de cas connu est de : 0.8054670992691397%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8046926628192276%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.035807975837400655%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08079979739752294%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.27114866052561704%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4200444217119875%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1473201669229725%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7101124705649875%
# Le taux de mortalité pour les 75 + ans est de : 3.8626253964696535%
# ############
# ################
#  replication = 12
# 0013
# log-configVaccin-configDpt75-PCG-NumRepli13.txt
# Le taux de mort de cas connu est de : 0.7940481060579797%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7932861154610439%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03684584088026653%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07143344449661494%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.26298585522405804%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.41278113481494993%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1103928065058806%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7238809677579612%
# Le taux de mortalité pour les 75 + ans est de : 3.824949825916684%
# ############
# ################
#  replication = 13
# 0014
# log-configVaccin-configDpt75-PCG-NumRepli14.txt
# Le taux de mort de cas connu est de : 0.8028480791782281%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8021065630133235%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.038844455148249864%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07570998244172748%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.27311002645404076%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4044872807710539%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.167009976762427%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.6593370043238849%
# Le taux de mortalité pour les 75 + ans est de : 3.8753245237886875%
# ############
# ################
#  replication = 14
# 0015
# log-configVaccin-configDpt75-PCG-NumRepli15.txt
# Le taux de mort de cas connu est de : 0.801782354871662%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8010444148787557%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.036556103897114015%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07691471326114357%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.252726987658561%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4030441357776761%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1804563990941024%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.714671113336285%
# Le taux de mortalité pour les 75 + ans est de : 3.8226336828914067%
# ############
# ################
#  replication = 15
# 0016
# log-configVaccin-configDpt75-PCG-NumRepli16.txt
# Le taux de mort de cas connu est de : 0.806151172411243%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8054315484780571%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03996244306321826%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07108433734939759%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2845352838649128%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.420253626750179%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.164919836230069%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.6786303170057402%
# Le taux de mortalité pour les 75 + ans est de : 3.854314002828854%
# ############
# ################
#  replication = 16
# 0017
# log-configVaccin-configDpt75-PCG-NumRepli17.txt
# Le taux de mort de cas connu est de : 0.8004995842190922%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7997513649758039%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.033771063245049825%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08158704896026751%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2641889622747117%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.42016659482834146%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1373555840821565%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7108226965569022%
# Le taux de mortalité pour les 75 + ans est de : 3.8333820235660725%
# ############
# ################
#  replication = 17
# 0018
# log-configVaccin-configDpt75-PCG-NumRepli18.txt
# Le taux de mort de cas connu est de : 0.8149585171277184%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8142058156766598%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0384391380314502%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07654808428346964%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2538774348643366%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4332704242352358%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1838452845507643%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7379055078426755%
# Le taux de mortalité pour les 75 + ans est de : 3.8702228604138975%
# ############
# ################
#  replication = 18
# 0019
# log-configVaccin-configDpt75-PCG-NumRepli19.txt
# Le taux de mort de cas connu est de : 0.8120227627078767%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8112502730413411%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.038769156809608546%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07712361067037289%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2731274582401512%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.43764981697323213%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.2107089299891205%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7584350382322338%
# Le taux de mortalité pour les 75 + ans est de : 3.7605600275933098%
# ############
# ################
#  replication = 19
# 0020
# log-configVaccin-configDpt75-PCG-NumRepli20.txt
# Le taux de mort de cas connu est de : 0.7989217053030948%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7981812329507907%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03525027696646188%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0885359912826101%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2821513950194471%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4072315941806081%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1358144030932817%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7132388136068792%
# Le taux de mortalité pour les 75 + ans est de : 3.7889643983075962%
# ############
# ################
#  replication = 20
# 0021
# log-configVaccin-configDpt75-PCG-NumRepli21.txt
# Le taux de mort de cas connu est de : 0.8135714497019539%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8128204050663543%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.038084134848926456%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08375580351210633%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2654077763735038%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.42095350536908976%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1557202110095437%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7299978059372167%
# Le taux de mortalité pour les 75 + ans est de : 3.899496026361698%
# ############
# ################
#  replication = 21
# 0022
# log-configVaccin-configDpt75-PCG-NumRepli22.txt
# Le taux de mort de cas connu est de : 0.80232418390082%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8015523987692011%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03761483187721278%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07671329710537836%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2794100595102282%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4183236249579926%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1444795369259722%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7209491994579298%
# Le taux de mortalité pour les 75 + ans est de : 3.8097694381453837%
# ############
# ################
#  replication = 22
# 0023
# log-configVaccin-configDpt75-PCG-NumRepli23.txt
# Le taux de mort de cas connu est de : 0.8040363605266868%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8032610718552449%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03771809418635849%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0877231633213031%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.26270911309552686%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4291665060941644%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1392874315014443%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7126900403350915%
# Le taux de mortalité pour les 75 + ans est de : 3.8479324360503324%
# ############
# ################
#  replication = 23
# 0024
# log-configVaccin-configDpt75-PCG-NumRepli24.txt
# Le taux de mort de cas connu est de : 0.8050291208283258%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8042770396361358%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03305039602150998%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07166929051428755%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.26577577035778943%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4249844858001492%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1862809450643745%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7179317352509227%
# Le taux de mortalité pour les 75 + ans est de : 3.8198400860698833%
# ############
# ################
#  replication = 24
# 0025
# log-configVaccin-configDpt75-PCG-NumRepli25.txt
# Le taux de mort de cas connu est de : 0.7947920436671091%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7940711814735504%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03518499186105408%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0742345812768348%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2569100590743769%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4252569626609638%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1107922351244353%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.693892896391595%
# Le taux de mortalité pour les 75 + ans est de : 3.8391269278238305%
# ############
# ################
#  replication = 25
# 0026
# log-configVaccin-configDpt75-PCG-NumRepli26.txt
# Le taux de mort de cas connu est de : 0.7935183597323292%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7927781315705984%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04317000035002703%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0728487482894631%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2532314945499369%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4139483823148944%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1288367818448775%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7272712253630491%
# Le taux de mortalité pour les 75 + ans est de : 3.7789605663074393%
# ############
# ################
#  replication = 26
# 0027
# log-configVaccin-configDpt75-PCG-NumRepli27.txt
# Le taux de mort de cas connu est de : 0.8009688542928196%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8002131685125724%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.040477951192931926%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0777486554291806%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2781812088034857%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4267345710967778%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1538093379770415%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.743166580711707%
# Le taux de mortalité pour les 75 + ans est de : 3.751351246067996%
# ############
# ################
#  replication = 27
# 0028
# log-configVaccin-configDpt75-PCG-NumRepli28.txt
# Le taux de mort de cas connu est de : 0.8103639311086654%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8095877803089744%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0399557771010726%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07913585255825724%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2791734378960237%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.44292406915917953%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.139148555244119%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7775671275784615%
# Le taux de mortalité pour les 75 + ans est de : 3.798423938983645%
# ############
# ################
#  replication = 28
# 0029
# log-configVaccin-configDpt75-PCG-NumRepli29.txt
# Le taux de mort de cas connu est de : 0.800404547274067%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7996590042684502%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0339046461056422%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.06913405575741985%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2578545314032637%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.41867661782106125%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1491090002531563%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7021680071566083%
# Le taux de mortalité pour les 75 + ans est de : 3.8501059193065332%
# ############
# ################
#  replication = 29
#                            Champs            R1            R2            R3  \
# 0            nbCasCovidConnuTotal  2.163401e+06  2.163437e+06  2.163430e+06
# 1              tauxDeMortCasConnu  8.124245e-01  8.042296e-01  8.025219e-01
# 2   tauxMortalitePopulationGobale  8.116659e-01  8.034920e-01  8.017833e-01
# 3               tauxDeMort0-15ans  0.000000e+00  0.000000e+00  0.000000e+00
# 4              tauxDeMort15-25ans  3.721839e-02  3.997299e-02  3.884159e-02
# 5              tauxDeMort25-35ans  8.217655e-02  7.153507e-02  7.658472e-02
# 6              tauxDeMort35-45ans  2.483799e-01  2.556800e-01  2.589910e-01
# 7              tauxDeMort45-55ans  4.169382e-01  4.220810e-01  4.024236e-01
# 8              tauxDeMort55-65ans  1.161543e+00  1.156782e+00  1.161690e+00
# 9              tauxDeMort65-75ans  1.740374e+00  1.722371e+00  1.732921e+00
# 10               tauxDeMort75+ans  3.907935e+00  3.848404e+00  3.827872e+00
# 11                 nbRandomGenere  0.000000e+00  0.000000e+00  0.000000e+00
#
#               R4            R5            R6            R7            R8  \
# 0   2.163361e+06  2.163411e+06  2.163451e+06  2.163392e+06  2.163454e+06
# 1   8.056446e-01  8.062268e-01  8.080608e-01  8.030445e-01  7.984454e-01
# 2   8.048774e-01  8.054777e-01  8.073249e-01  8.022913e-01  7.977194e-01
# 3   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 4   3.194030e-02  4.387004e-02  4.710169e-02  4.108941e-02  4.137504e-02
# 5   7.395736e-02  6.862784e-02  7.396688e-02  7.608328e-02  7.719679e-02
# 6   2.749843e-01  2.664513e-01  2.554155e-01  2.716986e-01  2.832426e-01
# 7   4.052423e-01  4.368761e-01  4.222905e-01  4.244986e-01  4.367424e-01
# 8   1.149932e+00  1.153894e+00  1.156993e+00  1.142365e+00  1.099901e+00
# 9   1.737817e+00  1.724973e+00  1.716194e+00  1.730962e+00  1.691911e+00
# 10  3.837323e+00  3.835227e+00  3.880021e+00  3.813191e+00  3.826002e+00
# 11  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#               R9  ...           R24           R25           R26           R27  \
# 0   2.163465e+06  ...  2.163335e+06  2.163400e+06  2.163459e+06  2.163403e+06
# 1   8.068076e-01  ...  8.040364e-01  8.050291e-01  7.947920e-01  7.935184e-01
# 2   8.060781e-01  ...  8.032611e-01  8.042770e-01  7.940712e-01  7.927781e-01
# 3   0.000000e+00  ...  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 4   4.309408e-02  ...  3.771809e-02  3.305040e-02  3.518499e-02  4.317000e-02
# 5   7.857074e-02  ...  8.772316e-02  7.166929e-02  7.423458e-02  7.284875e-02
# 6   2.830793e-01  ...  2.627091e-01  2.657758e-01  2.569101e-01  2.532315e-01
# 7   4.332012e-01  ...  4.291665e-01  4.249845e-01  4.252570e-01  4.139484e-01
# 8   1.137285e+00  ...  1.139287e+00  1.186281e+00  1.110792e+00  1.128837e+00
# 9   1.751075e+00  ...  1.712690e+00  1.717932e+00  1.693893e+00  1.727271e+00
# 10  3.792909e+00  ...  3.847932e+00  3.819840e+00  3.839127e+00  3.778961e+00
# 11  0.000000e+00  ...  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#              R28           R29           R30       Moyenne     Variance  \
# 0   2.163380e+06  2.163349e+06  2.163406e+06  2.163402e+06  1931.705747
# 1   8.009689e-01  8.103639e-01  8.004045e-01  8.036649e-01     0.000031
# 2   8.002132e-01  8.095878e-01  7.996590e-01  8.029147e-01     0.000031
# 3   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00     0.000000
# 4   4.047795e-02  3.995578e-02  3.390465e-02  3.833071e-02     0.000011
# 5   7.774866e-02  7.913585e-02  6.913406e-02  7.616638e-02     0.000029
# 6   2.781812e-01  2.791734e-01  2.578545e-01  2.679907e-01     0.000140
# 7   4.267346e-01  4.429241e-01  4.186766e-01  4.204106e-01     0.000123
# 8   1.153809e+00  1.139149e+00  1.149109e+00  1.150063e+00     0.000531
# 9   1.743167e+00  1.777567e+00  1.702168e+00  1.721608e+00     0.000531
# 10  3.751351e+00  3.798424e+00  3.850106e+00  3.829430e+00     0.001523
# 11  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00     0.000000
#
#                                  Intervalle95%
# 0     (2163385.1216950268, 2163417.9449716397)
# 1     (0.8015977518479115, 0.8057321408883639)
# 2     (0.8008488590519978, 0.8049805793533393)
# 3                                   (nan, nan)
# 4   (0.03706862288140252, 0.03959280417722937)
# 5   (0.07414796942242613, 0.07818479977238463)
# 6   (0.26356923754524614, 0.27241210088935947)
# 7    (0.4162613785135135, 0.42455988632552255)
# 8      (1.1414622813938677, 1.158663394809632)
# 9     (1.7130012201016842, 1.7302152434072071)
# 10    (3.8148599695758656, 3.8440000109372536)
# 11                                  (nan, nan)
#
# [12 rows x 34 columns]
# /tmp/ipykernel_132203/1982382761.py:362: DeprecationWarning: Use of keyword argument 'alpha' for method 'interval' is deprecated and wil be removed in SciPy 1.11.0. Use first positional argument or keyword argument 'confidence' instead.
#   listIntervalle95 = [st.t.interval(alpha=0.95, df=len(r)-1, loc=np.mean(r), scale=st.sem(r)) for r in zip(*listResReplicationTruncated)]
# /usr/lib/python3/dist-packages/scipy/stats/_distn_infrastructure.py:2351: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /usr/lib/python3/dist-packages/scipy/stats/_distn_infrastructure.py:2352: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
