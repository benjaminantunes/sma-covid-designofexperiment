# %%
# !make clean
# !make
# Out:
# rm -rf *.o
# rm -rf *.d
# g++ -o City.o -c City.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o Human.o -c Human.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o main.o -c main.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o Position.o -c Position.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o RandMT.o -c RandMT.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o SimulationParams.o -c SimulationParams.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o World.o -c World.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -O2 City.o Human.o main.o Position.o RandMT.o SimulationParams.o World.o  -o exe

# %%
# !./replicationSimulation.sh 1 configToyEpidemicalContext configToyState
# Out:
# mts000M000000 0 configToyEpidemicalContext configToyState
# Nom de la commande :./exe
# Nom du fichier MT a utiliser :mts000M000000
# Num�ro de la replication :0
# config �pid�mie :configToyEpidemicalContext
# config g�ographique :configToyState
# ./mts-0000-0999/mts000M000000
# log file name : log-configToyEpidemicalContext-configToyState-MT-mts000M000000NumRepli0.txt
# La ville a pour coord X : 500 , coordY : 0, taille : 500 , nbHab : 10000
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# ***************STATISTICS******************
# Safe : 1771
# Contamined : 552
# Recovered : 96153
# Dead : 1524
#
# real	0m29,916s
# user	0m27,911s
# sys	0m0,460s

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st
import pandas as pd
import csv
from statistics import mean,variance
'''
Ce qu'on a comme résultats pour le moment :
- Les listes
- Taux de mortalité des gens contaminé
- Taux de mortalité par tranche d'age des gens contaminé
- Reffectif
- Taux d'incidence

On peut donc envisager beaucoup d'autres résultats.


'''

NB_REPLICATION = 30
NOM_EXPERIENCE = "configVaccin"
listDptConfig = ["configDpt75"]  

figureNouvCas = plt.figure()
axes = figureNouvCas.add_subplot()

pasFigure = 6 * NB_REPLICATION
compteurFigure = 0
for nbDpt in listDptConfig:

    compteurFigure = compteurFigure + pasFigure
    listResReplication = [[] for x in range(0,NB_REPLICATION)]


    for replication in listResReplication:

        listNumIteration = []
        listNbNouvCas = []
        listNbPersonneHosp = []
        listNbPersonneRea = []
        listNbNouvHosp = []
        listNbNouvRea = []
        listNbNouvMort = []
        nbCasCovidConnuTotal = 0
        listAgeMort = []
        listAgeNouvCasSymptomatique = []
        listReffectif = []
        listTauxIncidence = []
        
        temp = len(listDptConfig) * (listResReplication.index(replication)) + listDptConfig.index(nbDpt)
        stringFormat = f"{temp:04}"
        print(stringFormat)
        print("log-"+NOM_EXPERIENCE+"-"+nbDpt+ "-MT-mts000M00"+stringFormat+"NumRepli"+str(listResReplication.index(replication))+".txt")
        f = open("log-"+NOM_EXPERIENCE+"-"+nbDpt+ "-MT-mts000M00"+stringFormat+"NumRepli"+str(listResReplication.index(replication))+".txt", "r")
        fileLines = f.readlines()
        i = 0
        for line in fileLines:
            if("CompteurRand:" in line):
                listSplit = line.split(":")
                nbRandomGenere = (int(listSplit[1]))
            elif("NbHumainSimuDepart:" in line):
                listSplit = line.split(":")
                nbHumainSimuDepart = (int(listSplit[1]))
            elif("##" not in line):
                if(i == 0):
                    listNumIteration.append(int(line))
                    i = i + 1
                elif(i==1):
                    listNbNouvCas.append(int(line))
                    i = i + 1
                elif(i==2):
                    listNbPersonneHosp.append(int(line))
                    i = i + 1
                elif(i==3):
                    listNbPersonneRea.append(int(line))
                    i = i + 1
                elif(i==4):
                    listNbNouvHosp.append(int(line))
                    i = i + 1
                elif(i==5):
                    listNbNouvRea.append(int(line))
                    i = i + 1
                elif(i==6):
                    listNbNouvMort.append(int(line))
                    i = i + 1
                elif(i==7):
                    nbCasCovidConnuTotal = (int(line))
                    i = i + 1
                elif(i==8):
                    listReffectif.append(float(line))
                    i = i + 1
                elif(i==9):
                    listTauxIncidence.append(float(line))
                    i = i + 1
                elif("AgeC:" in line):
                    listSplit = line.split(":")
                    listAgeNouvCasSymptomatique.append(int(listSplit[1]))
                elif("AgeD:" in line):
                    listSplit = line.split(":")
                    listAgeMort.append(int(listSplit[1]))

            else:
                i = 0

        f.close()


        #label=str(ville)+ "-MT-"+stringFormat+"config"+NOM_EXPERIENCE+"NumRepli"+str(listResReplication.index(replication)+1) 
        axes.plot(listNumIteration, listNbNouvCas, label="test")
        """
        plt.figure((listResReplication.index(replication)*6)+compteurFigure)
        print("Courbe des nouveaux cas sur la réplication num : " +str(listResReplication.index(replication)))
        plt.plot(listNumIteration, listNbNouvCas)  # Matplotlib plot.
        plt.xlabel("Jour")
        plt.ylabel("Nouv Cas")
        plt.title(label="Courbe nouvCas"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("nouvCas"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        string = "nouvCas"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv"
        with open(string, "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listNbNouvCas)

        plt.figure((listResReplication.index(replication)*6+1)+compteurFigure)
        print("Courbe des nouvelles hospitalisation sur la réplication num : " +str(listResReplication.index(replication)))
        plt.plot(listNumIteration, listNbNouvHosp)
        plt.xlabel("Jour")
        plt.ylabel("Nouv Hosp")
        plt.title(label="Courbe nouvHosp"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("nouvHosp"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("nouvHosp"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listNbNouvHosp)

        plt.figure((listResReplication.index(replication)*6+2)+compteurFigure)
        print("Courbe des nouvelles réanimation sur la réplication num : " +str(listResReplication.index(replication)))
        plt.plot(listNumIteration, listNbNouvRea)
        plt.xlabel("Jour")
        plt.ylabel("Nouv Rea")
        plt.title(label="Courbe nouvRea"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("nouvRea"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("nouvRea"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listNbNouvRea)

        plt.figure((listResReplication.index(replication)*6+3)+compteurFigure)
        print("Courbe des nouveaux morts sur la réplication num : " +str(listResReplication.index(replication)))
        plt.plot(listNumIteration, listNbNouvMort)
        plt.xlabel("Jour")
        plt.ylabel("Nouv Mort")
        plt.title(label="Courbe nouvMort"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("nouvMort"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("nouvMort"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listNbNouvMort)

        print("Courbe de Reffectif sur la réplication num : " +str(listResReplication.index(replication)))
        plt.figure((listResReplication.index(replication)*6+4)+compteurFigure)
        plt.plot(listNumIteration, listReffectif)
        plt.xlabel("Jour")
        plt.ylabel("Reffectif")
        plt.title(label="Courbe Reffectif"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("Reffectif"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("Reffectif"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listReffectif)
            
        print("Courbe du taux d'incidence sur la réplication num : " +str(listResReplication.index(replication)))
        plt.figure((listResReplication.index(replication)*6+5)+compteurFigure)
        plt.plot(listNumIteration, listTauxIncidence)
        plt.xlabel("Jour")
        plt.ylabel("Taux Incidence")
        plt.title(label="Courbe Taux incidence"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("TauxIncidence"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("TauxIncidence"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listTauxIncidence)
        """
        nbMortTotal = sum(listNbNouvMort)
        try:
            tauxDeMortCasConnu = (nbMortTotal / nbCasCovidConnuTotal) * 100
        except:
            tauxDeMortCasConnu = 0
        tauxMortalitePopulationGobale = (nbMortTotal / nbHumainSimuDepart) * 100

        print("Le taux de mort de cas connu est de : " + str(tauxDeMortCasConnu) + "%")
        print("Le taux de mortalité du département sur l'ensemble de la population est de : " + str(tauxMortalitePopulationGobale) + "%")

        ## IL ME FAUT L'AGE DES GENS CONTAMINE AUSSI ... 


        nbAge0 = 0
        nbAge1 = 0
        nbAge2 = 0
        nbAge3 = 0
        nbAge4 = 0
        nbAge5 = 0
        nbAge6 = 0
        nbAge7 = 0

        for i in listAgeNouvCasSymptomatique:
            if i == 0:
                nbAge0 = nbAge0 + 1
            elif i == 1:
                nbAge1 = nbAge1 + 1
            elif i == 2:
                nbAge2 = nbAge2 + 1
            elif i == 3:
                nbAge3 = nbAge3 + 1
            elif i == 4:
                nbAge4 = nbAge4 + 1
            elif i == 5:
                nbAge5 = nbAge5 + 1
            elif i == 6:
                nbAge6 = nbAge6 + 1
            elif i == 7:
                nbAge7 = nbAge7 + 1


        nbAgeMort0 = 0
        nbAgeMort1 = 0
        nbAgeMort2 = 0
        nbAgeMort3 = 0
        nbAgeMort4 = 0
        nbAgeMort5 = 0
        nbAgeMort6 = 0
        nbAgeMort7 = 0

        for i in listAgeMort:
            if i == 0:
                nbAgeMort0 = nbAgeMort0 + 1
            elif i == 1:
                nbAgeMort1 = nbAgeMort1 + 1
            elif i == 2:
                nbAgeMort2 = nbAgeMort2 + 1
            elif i == 3:
                nbAgeMort3 = nbAgeMort3 + 1
            elif i == 4:
                nbAgeMort4 = nbAgeMort4 + 1
            elif i == 5:
                nbAgeMort5 = nbAgeMort5 + 1
            elif i == 6:
                nbAgeMort6 = nbAgeMort6 + 1
            elif i == 7:
                nbAgeMort7 = nbAgeMort7 + 1

        try :
            print("Le taux de mortalité pour les 0 - 15 ans est de : " + str( (nbAgeMort0/nbAge0) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 0 n'a été malade")
        try :
            print("Le taux de mortalité pour les 15 - 25 ans est de : " + str( (nbAgeMort1/nbAge1) * 100) + "%") 
        except ZeroDivisionError:
            print ("Aucun age 1 n'a été malade")
        try :
            print("Le taux de mortalité pour les 25 - 35 ans est de : " + str( (nbAgeMort2/nbAge2) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 2 n'a été malade")
        try:
            print("Le taux de mortalité pour les 35 - 45 ans est de : " + str( (nbAgeMort3/nbAge3) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 3 n'a été malade")
        try :
            print("Le taux de mortalité pour les 45 - 55 ans est de : " + str( (nbAgeMort4/nbAge4) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 4 n'a été malade")
        try:
            print("Le taux de mortalité pour les 55 - 65 ans est de : " + str( (nbAgeMort5/nbAge5) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 5 n'a été malade")
        try:
            print("Le taux de mortalité pour les 65 - 75 ans est de : " + str( (nbAgeMort6/nbAge6) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 6 n'a été malade")
        try:
            print("Le taux de mortalité pour les 75 + ans est de : " + str( (nbAgeMort7/nbAge7) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucune age 7 n'a été malade")

        print("############\n################")
        print(" replication = " + str(listResReplication.index(replication)))
        replication.append(listNumIteration)
        replication.append(listNbNouvCas)
        replication.append(listNbPersonneHosp)
        replication.append(listNbPersonneRea)
        replication.append(listNbNouvHosp)
        replication.append(listNbNouvMort)
        replication.append(listReffectif)
        replication.append(nbCasCovidConnuTotal)
        replication.append(tauxDeMortCasConnu)
        replication.append(tauxMortalitePopulationGobale)
        try :
            replication.append((nbAgeMort0/nbAge0) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort1/nbAge1) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort2/nbAge2) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort3/nbAge3) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort4/nbAge4) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort5/nbAge5) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort6/nbAge6) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort7/nbAge7) * 100)
        except ZeroDivisionError:
            replication.append(0)
            
        replication.append(int(nbRandomGenere))



    dataframeResultats = pd.DataFrame({"Champs":["nbCasCovidConnuTotal","tauxDeMortCasConnu","tauxMortalitePopulationGobale", "tauxDeMort0-15ans", "tauxDeMort15-25ans","tauxDeMort25-35ans","tauxDeMort35-45ans","tauxDeMort45-55ans","tauxDeMort55-65ans","tauxDeMort65-75ans","tauxDeMort75+ans","nbRandomGenere"]})
    numRepli = 1
    listResReplicationTruncated = []
    for replication in listResReplication:
        nomRepli = "R"+str(numRepli)
        dataframeResultats[nomRepli] = replication[-12:]
        listResReplicationTruncated.append(replication[-12:])
        numRepli = numRepli + 1

    
    if(NB_REPLICATION > 1):
        listMoyenne = [mean(list(map(float,list(r)))) for r in zip(*listResReplicationTruncated)]

        listVariance = [variance(list(map(float,list(r)))) for r in zip(*listResReplicationTruncated)]

        '''
        Confidence Intervals Using the t Distribution
        If we’re working with a small sample (n <30), we can use the t.interval() function from the scipy.stats library to calculate a confidence interval for a population mean.

        The following example shows how to calculate a confidence interval for the true population mean height (in inches) of a certain species of plant, using a sample of 15 plants:



        ###########
        Confidence Intervals Using the Normal Distribution
        If we’re working with larger samples (n≥30), we can assume that the sampling distribution of the sample mean is normally distributed (thanks to the Central Limit Theorem) and can instead use the norm.interval() function from the scipy.stats library.




        '''

        listIntervalle95 = [st.t.interval(alpha=0.95, df=len(r)-1, loc=np.mean(r), scale=st.sem(r)) for r in zip(*listResReplicationTruncated)]

        dataframeResultats["Moyenne"] = listMoyenne
        dataframeResultats["Variance"] = listVariance
        dataframeResultats["Intervalle95%"] = listIntervalle95

    print(dataframeResultats)

    dataframeResultats.to_csv("stats"+nbDpt + str(NOM_EXPERIENCE)+".csv", sep="|")
    dataframeResultats.to_html("stats"+nbDpt + str(NOM_EXPERIENCE)+".html",float_format='%.3f')
# Out:
# 0000
# log-configVaccin-configDpt75-MT-mts000M000000NumRepli0.txt
# Le taux de mort de cas connu est de : 0.8226761811482673%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8145752585060747%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03997037489860457%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07303149686167429%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2776011946631358%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.40973011640301576%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1910526880011236%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7488545210589501%
# Le taux de mortalité pour les 75 + ans est de : 3.9432718844223573%
# ############
# ################
#  replication = 0
# 0001
# log-configVaccin-configDpt75-MT-mts000M000001NumRepli1.txt
# Le taux de mort de cas connu est de : 0.8264227693464311%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8183158671539003%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03942725086661878%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08264328887880605%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.27515590288349856%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4470327977185425%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.200695647014762%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.79144407310792%
# Le taux de mortalité pour les 75 + ans est de : 3.8768803927548925%
# ############
# ################
#  replication = 1
# 0002
# log-configVaccin-configDpt75-MT-mts000M000002NumRepli2.txt
# Le taux de mort de cas connu est de : 0.8258408103117013%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8178078832634548%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.039501885139469034%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07155169610043256%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2781478888612874%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.43459534266307037%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1815153238733314%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7810312860173385%
# Le taux de mortalité pour les 75 + ans est de : 3.9179762511267002%
# ############
# ################
#  replication = 2
# 0003
# log-configVaccin-configDpt75-MT-mts000M000003NumRepli3.txt
# Le taux de mort de cas connu est de : 0.8335509747225073%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8253814612664593%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.038886510308853164%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07148543484265081%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.27526381013181117%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.43727765542944264%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1868183938341712%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.821073492430929%
# Le taux de mortalité pour les 75 + ans est de : 3.9508379449357487%
# ############
# ################
#  replication = 3
# 0004
# log-configVaccin-configDpt75-MT-mts000M000004NumRepli4.txt
# Le taux de mort de cas connu est de : 0.8283211199498529%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8201630813009744%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04030033531444043%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08800496396663111%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.29322974305696714%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.41867818823968533%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.20060699833373%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7675727193650557%
# Le taux de mortalité pour les 75 + ans est de : 3.928204775541681%
# ############
# ################
#  replication = 4
# 0005
# log-configVaccin-configDpt75-MT-mts000M000005NumRepli5.txt
# Le taux de mort de cas connu est de : 0.8285424574371527%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8203478027156819%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.030714223835812782%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07274086777010635%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2951235243823781%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.42058910702440266%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.2079775460036262%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7426904973338504%
# Le taux de mortalité pour les 75 + ans est de : 3.957325454554349%
# ############
# ################
#  replication = 5
# 0006
# log-configVaccin-configDpt75-MT-mts000M000006NumRepli6.txt
# Le taux de mort de cas connu est de : 0.8237995234610773%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8157297673479962%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.042807882934185824%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0851395071638814%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.27651820945971434%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.43425609812069493%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1433668804850332%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7718586664563243%
# Le taux de mortalité pour les 75 + ans est de : 3.9387856269908657%
# ############
# ################
#  replication = 6
# 0007
# log-configVaccin-configDpt75-MT-mts000M000007NumRepli7.txt
# Le taux de mort de cas connu est de : 0.8267792917157908%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8186853099833149%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04579059218585501%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08598801035100954%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.28493464594231954%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.44896113713272434%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.15214704859441%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7721213934317244%
# Le taux de mortalité pour les 75 + ans est de : 3.9378845879089748%
# ############
# ################
#  replication = 7
# 0008
# log-configVaccin-configDpt75-MT-mts000M000008NumRepli8.txt
# Le taux de mort de cas connu est de : 0.831965378301746%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8238575095951229%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0364461478773058%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08250322087697266%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.27690527359894196%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.44816918121715543%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.197649223828322%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.792953758258939%
# Le taux de mortalité pour les 75 + ans est de : 3.922549510049142%
# ############
# ################
#  replication = 8
# 0009
# log-configVaccin-configDpt75-MT-mts000M000009NumRepli9.txt
# Le taux de mort de cas connu est de : 0.8275315961310042%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8194703759958215%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03486777668952008%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08430609597924774%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.26421173069974707%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4390231822636049%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1553543603642191%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7803660565723793%
# Le taux de mortalité pour les 75 + ans est de : 3.9709048817213795%
# ############
# ################
#  replication = 9
# 0010
# log-configVaccin-configDpt75-MT-mts000M000010NumRepli10.txt
# Le taux de mort de cas connu est de : 0.826422386617572%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.818408227861254%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.036435153262709206%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.09052772815816487%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2773998488284203%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.45748858932172803%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1566125976793749%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7653625699813384%
# Le taux de mortalité pour les 75 + ans est de : 3.9390900869018126%
# ############
# ################
#  replication = 10
# 0011
# log-configVaccin-configDpt75-MT-mts000M000011NumRepli11.txt
# Le taux de mort de cas connu est de : 0.8332334504101107%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8250581987907213%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04367087113552134%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07476878565739642%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2680184777760137%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4488510752327996%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1736984674756021%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7829138119662384%
# Le taux de mortalité pour les 75 + ans est de : 3.9687957094100437%
# ############
# ################
#  replication = 11
# 0012
# log-configVaccin-configDpt75-MT-mts000M000012NumRepli12.txt
# Le taux de mort de cas connu est de : 0.8233869120938625%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8152679638112276%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04190097272912392%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07866767772204357%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.26725973952541604%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.42524982545716117%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1883446385188596%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7759926746025139%
# Le taux de mortalité pour les 75 + ans est de : 3.8988986051607095%
# ############
# ################
#  replication = 12
# 0013
# log-configVaccin-configDpt75-MT-mts000M000013NumRepli13.txt
# Le taux de mort de cas connu est de : 0.8304090621624495%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8222411972164331%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03605015673981191%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07305520944522685%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.27312947691566847%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.43534355127536273%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.2097417017947776%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7786594139614575%
# Le taux de mortalité pour les 75 + ans est de : 3.9446414364152487%
# ############
# ################
#  replication = 13
# 0014
# log-configVaccin-configDpt75-MT-mts000M000014NumRepli14.txt
# Le taux de mort de cas connu est de : 0.8214804090937923%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8133745693104766%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.043252255015295574%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07261751664320458%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.28898362802388633%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.42694899213199045%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1800864581093407%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.774160056480751%
# Le taux de mortalité pour les 75 + ans est de : 3.876970539543429%
# ############
# ################
#  replication = 14
# 0015
# log-configVaccin-configDpt75-MT-mts000M000015NumRepli15.txt
# Le taux de mort de cas connu est de : 0.8224294009533373%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8143905370913673%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.038397041076997825%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07522415585150913%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2758802386194697%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4236301683938738%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1826866270579974%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.762257150090686%
# Le taux de mortalité pour les 75 + ans est de : 3.9259437648365583%
# ############
# ################
#  replication = 15
# 0016
# log-configVaccin-configDpt75-MT-mts000M000016NumRepli16.txt
# Le taux de mort de cas connu est de : 0.8382243747364808%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8299533162804681%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.042807882934185824%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07662276060860364%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2810244619020246%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4245662577466578%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.2039224690224193%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7714338076038787%
# Le taux de mortalité pour les 75 + ans est de : 4.032044426565673%
# ############
# ################
#  replication = 16
# 0017
# log-configVaccin-configDpt75-MT-mts000M000017NumRepli17.txt
# Le taux de mort de cas connu est de : 0.8336446209729056%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8255200023274898%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03561769299114255%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08001364699766052%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.27285694392695714%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4545054790424428%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1982224456899484%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7919836465392236%
# Le taux de mortalité pour les 75 + ans est de : 3.945043967778286%
# ############
# ################
#  replication = 17
# 0018
# log-configVaccin-configDpt75-MT-mts000M000018NumRepli18.txt
# Le taux de mort de cas connu est de : 0.8303475398336414%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8221488365090793%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04082770316689501%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07042624065536879%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2699759687593872%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.42893261903499%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.2193540498782869%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7972384811646405%
# Le taux de mortalité pour les 75 + ans est de : 3.930934402439924%
# ############
# ################
#  replication = 18
# 0019
# log-configVaccin-configDpt75-MT-mts000M000019NumRepli19.txt
# Le taux de mort de cas connu est de : 0.8310678235108383%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8228877221679091%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04047405730812153%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07550693161751273%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2789190004146093%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.44655978978755656%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.165388407413288%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7639309269496628%
# Le taux de mortalité pour les 75 + ans est de : 3.976517933890756%
# ############
# ################
#  replication = 19
# 0020
# log-configVaccin-configDpt75-MT-mts000M000020NumRepli20.txt
# Le taux de mort de cas connu est de : 0.8272849672355232%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8191932938737604%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03729190137665998%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08028838940679857%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2856971009262601%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.42800226858815615%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1917242401229882%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7834426888055706%
# Le taux de mortalité pour les 75 + ans est de : 3.907972910197795%
# ############
# ################
#  replication = 20
# 0021
# log-configVaccin-configDpt75-MT-mts000M000021NumRepli21.txt
# Le taux de mort de cas connu est de : 0.8276915715646812%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8196089170568521%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.043526509997372724%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08461915307969181%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.28544315237693557%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4490087187530911%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1682234347544622%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7254728919674969%
# Le taux de mortalité pour les 75 + ans est de : 3.9726780246525872%
# ############
# ################
#  replication = 21
# 0022
# log-configVaccin-configDpt75-MT-mts000M000022NumRepli22.txt
# Le taux de mort de cas connu est de : 0.82037009920733%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8124047818832626%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04104673072562801%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0836470096194061%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.280718368451314%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4530503978779841%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1662617403928772%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7481442073500195%
# Le taux de mortalité pour les 75 + ans est de : 3.873790360157541%
# ############
# ################
#  replication = 22
# 0023
# log-configVaccin-configDpt75-MT-mts000M000023NumRepli23.txt
# Le taux de mort de cas connu est de : 0.8397157325557859%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8314772679518044%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.036046907998103624%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07500172301255568%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2728871915923682%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4489052640494643%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.2339200520323281%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.771450012507296%
# Le taux de mortalité pour les 75 + ans est de : 3.993682310469314%
# ############
# ################
#  replication = 23
# 0024
# log-configVaccin-configDpt75-MT-mts000M000024NumRepli24.txt
# Le taux de mort de cas connu est de : 0.8311666507323192%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8230262632289395%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04105186610054189%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07309525936634531%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.26122007791564394%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4490044122638308%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1966899592718503%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.8304283210597085%
# Le taux de mortalité pour les 75 + ans est de : 3.9037798659566207%
# ############
# ################
#  replication = 24
# 0025
# log-configVaccin-configDpt75-MT-mts000M000025NumRepli25.txt
# Le taux de mort de cas connu est de : 0.8325801309406214%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8244116738392452%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03993234990134361%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08220753555577154%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2736009044657999%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4464869642068051%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1756743762897655%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7791357413134967%
# Le taux de mortalité pour les 75 + ans est de : 3.9789491254166727%
# ############
# ################
#  replication = 25
# 0026
# log-configVaccin-configDpt75-MT-mts000M000026NumRepli26.txt
# Le taux de mort de cas connu est de : 0.8242728314618376%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8160530298237342%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.038020280095795424%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07538146669638696%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.28472370907096684%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.42533381298008766%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1737576557471863%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7891642516904833%
# Le taux de mortalité pour les 75 + ans est de : 3.9046329811757547%
# ############
# ################
#  replication = 26
# 0027
# log-configVaccin-configDpt75-MT-mts000M000027NumRepli27.txt
# Le taux de mort de cas connu est de : 0.8349179564029265%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8266745111694113%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0415596636019682%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08227417158420336%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.26375905497610386%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.42998909140974995%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.167394285756533%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.8059661605785773%
# Le taux de mortalité pour les 75 + ans est de : 4.025522669065562%
# ############
# ################
#  replication = 27
# 0028
# log-configVaccin-configDpt75-MT-mts000M000028NumRepli28.txt
# Le taux de mort de cas connu est de : 0.8175150620038306%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8095415999552975%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04227866336788701%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07662804180890831%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.25543743661019497%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4451101321585903%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1647575523769957%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7586350395339159%
# Le taux de mortalité pour les 75 + ans est de : 3.8937235574206293%
# ############
# ################
#  replication = 28
# 0029
# log-configVaccin-configDpt75-MT-mts000M000029NumRepli29.txt
# Le taux de mort de cas connu est de : 0.8323154992004231%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8241807720708609%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.034461962608770574%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08946318043630505%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.26951438476566175%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.42353903718045016%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1504746635789411%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.8197353339585287%
# Le taux de mortalité pour les 75 + ans est de : 4.002237915989812%
# ############
# ################
#  replication = 29
#                            Champs            R1            R2            R3  \
# 0            nbCasCovidConnuTotal  2.144100e+06  2.144181e+06  2.144360e+06
# 1              tauxDeMortCasConnu  8.226762e-01  8.264228e-01  8.258408e-01
# 2   tauxMortalitePopulationGobale  8.145753e-01  8.183159e-01  8.178079e-01
# 3               tauxDeMort0-15ans  0.000000e+00  0.000000e+00  0.000000e+00
# 4              tauxDeMort15-25ans  3.997037e-02  3.942725e-02  3.950189e-02
# 5              tauxDeMort25-35ans  7.303150e-02  8.264329e-02  7.155170e-02
# 6              tauxDeMort35-45ans  2.776012e-01  2.751559e-01  2.781479e-01
# 7              tauxDeMort45-55ans  4.097301e-01  4.470328e-01  4.345953e-01
# 8              tauxDeMort55-65ans  1.191053e+00  1.200696e+00  1.181515e+00
# 9              tauxDeMort65-75ans  1.748855e+00  1.791444e+00  1.781031e+00
# 10               tauxDeMort75+ans  3.943272e+00  3.876880e+00  3.917976e+00
# 11                 nbRandomGenere  3.408057e+09  3.407958e+09  3.407984e+09
#
#               R4            R5            R6            R7            R8  \
# 0   2.144200e+06  2.144096e+06  2.144006e+06  2.144211e+06  2.144224e+06
# 1   8.335510e-01  8.283211e-01  8.285425e-01  8.237995e-01  8.267793e-01
# 2   8.253815e-01  8.201631e-01  8.203478e-01  8.157298e-01  8.186853e-01
# 3   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 4   3.888651e-02  4.030034e-02  3.071422e-02  4.280788e-02  4.579059e-02
# 5   7.148543e-02  8.800496e-02  7.274087e-02  8.513951e-02  8.598801e-02
# 6   2.752638e-01  2.932297e-01  2.951235e-01  2.765182e-01  2.849346e-01
# 7   4.372777e-01  4.186782e-01  4.205891e-01  4.342561e-01  4.489611e-01
# 8   1.186818e+00  1.200607e+00  1.207978e+00  1.143367e+00  1.152147e+00
# 9   1.821073e+00  1.767573e+00  1.742690e+00  1.771859e+00  1.772121e+00
# 10  3.950838e+00  3.928205e+00  3.957325e+00  3.938786e+00  3.937885e+00
# 11  3.407760e+09  3.407910e+09  3.407877e+09  3.408045e+09  3.407976e+09
#
#               R9  ...           R24           R25           R26           R27  \
# 0   2.144320e+06  ...  2.144178e+06  2.144215e+06  2.144178e+06  2.143829e+06
# 1   8.319654e-01  ...  8.397157e-01  8.311667e-01  8.325801e-01  8.242728e-01
# 2   8.238575e-01  ...  8.314773e-01  8.230263e-01  8.244117e-01  8.160530e-01
# 3   0.000000e+00  ...  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 4   3.644615e-02  ...  3.604691e-02  4.105187e-02  3.993235e-02  3.802028e-02
# 5   8.250322e-02  ...  7.500172e-02  7.309526e-02  8.220754e-02  7.538147e-02
# 6   2.769053e-01  ...  2.728872e-01  2.612201e-01  2.736009e-01  2.847237e-01
# 7   4.481692e-01  ...  4.489053e-01  4.490044e-01  4.464870e-01  4.253338e-01
# 8   1.197649e+00  ...  1.233920e+00  1.196690e+00  1.175674e+00  1.173758e+00
# 9   1.792954e+00  ...  1.771450e+00  1.830428e+00  1.779136e+00  1.789164e+00
# 10  3.922550e+00  ...  3.993682e+00  3.903780e+00  3.978949e+00  3.904633e+00
# 11  3.407818e+09  ...  3.407555e+09  3.407828e+09  3.407797e+09  3.408000e+09
#
#              R28           R29           R30       Moyenne      Variance  \
# 0   2.144043e+06  2.144303e+06  2.144259e+06  2.144186e+06  1.724876e+04
# 1   8.349180e-01  8.175151e-01  8.323155e-01  8.284636e-01  2.739822e-05
# 2   8.266745e-01  8.095416e-01  8.241808e-01  8.203386e-01  2.679583e-05
# 3   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 4   4.155966e-02  4.227866e-02  3.446196e-02  3.944545e-02  1.122942e-05
# 5   8.227417e-02  7.662804e-02  8.946318e-02  7.891437e-02  3.435708e-05
# 6   2.637591e-01  2.554374e-01  2.695144e-01  2.761180e-01  8.343008e-05
# 7   4.299891e-01  4.451101e-01  4.235390e-01  4.369606e-01  1.594395e-04
# 8   1.167394e+00  1.164758e+00  1.150475e+00  1.182804e+00  4.756418e-04
# 9   1.805966e+00  1.758635e+00  1.819735e+00  1.778182e+00  5.277552e-04
# 10  4.025523e+00  3.893724e+00  4.002238e+00  3.941349e+00  1.711730e-03
# 11  3.407706e+09  3.408221e+09  3.407776e+09  3.407902e+09  2.509743e+10
#
#                                  Intervalle95%
# 0       (2144137.125539239, 2144235.207794094)
# 1     (0.8265090215296601, 0.8304180840847263)
# 2      (0.8184056413671453, 0.822271491922748)
# 3                                   (nan, nan)
# 4   (0.03819415729212318, 0.04069674952017957)
# 5   (0.07672565533689805, 0.08110308911073368)
# 6   (0.27270734213264414, 0.27952873050221616)
# 7     (0.4322456671943591, 0.4416756163459816)
# 8      (1.174660303236886, 1.1909476923162172)
# 9       (1.76960422424227, 1.7867606859003227)
# 10    (3.9259001099640796, 3.9567980169326424)
# 11     (3407842934.236104, 3407961245.4972296)
#
# [12 rows x 34 columns]
# /tmp/ipykernel_132186/4101639869.py:360: DeprecationWarning: Use of keyword argument 'alpha' for method 'interval' is deprecated and wil be removed in SciPy 1.11.0. Use first positional argument or keyword argument 'confidence' instead.
#   listIntervalle95 = [st.t.interval(alpha=0.95, df=len(r)-1, loc=np.mean(r), scale=st.sem(r)) for r in zip(*listResReplicationTruncated)]
# /usr/lib/python3/dist-packages/scipy/stats/_distn_infrastructure.py:2351: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /usr/lib/python3/dist-packages/scipy/stats/_distn_infrastructure.py:2352: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
import matplotlib.pyplot as plt
plt.plot([44,221,588,917,1990],[70000,161000,264000,330000,492000])

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

x = np.array([44,221,588,917,1990]).reshape(-1,1)
y = np.array([70000,161000,264000,330000,492000])

model = LinearRegression()
model.fit(np.log(x),y)

x_pred = np.array([50,100,220,500,1000,1500,3000,5000,8000,12000]).reshape(-1,1)
y_pred = model.predict(np.log(x_pred))
print(y_pred)

plt.plot([44,221,588,917,1990],[70000,161000,264000,330000,492000],color='r')
plt.plot([50,100,220,500,1000,1500,3000,5000,8000,12000],y_pred)
# Out:
# [ 43885.06248518 116924.96278337 200008.1067469  286518.35933351
#  359558.2596317  402283.86236256 475323.76266075 529151.65618184
#  578677.96052628 621403.56325713]
