# %%
# !make clean
# !make
# Out:
# rm -rf *.o
# rm -rf *.d
# g++ -o City.o -c City.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o Human.o -c Human.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o main.o -c main.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o Position.o -c Position.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o RandomGenerator.o -c RandomGenerator.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o SimulationParams.o -c SimulationParams.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o World.o -c World.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -O2 City.o Human.o main.o Position.o RandomGenerator.o SimulationParams.o World.o  -o exe

# %%
# !./replicationSimulation.sh 1 configToyEpidemicalContext configToyState
# Out:
# mts000M000000 0 configToyEpidemicalContext configToyState
# Nom de la commande :./exe
# Nom du fichier MT a utiliser :mts000M000000
# Num�ro de la replication :0
# config �pid�mie :configToyEpidemicalContext
# config g�ographique :configToyState
# log file name : log-configToyEpidemicalContext-configToyState-MRG-NumRepli0.txt
# La ville a pour coord X : 500 , coordY : 0, taille : 500 , nbHab : 10000
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# ***************STATISTICS******************
# Safe : 1694
# Contamined : 567
# Recovered : 96265
# Dead : 1474
#
# real	0m25,221s
# user	0m25,140s
# sys	0m0,064s

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st
import pandas as pd
import csv
from statistics import mean,variance
'''
Ce qu'on a comme résultats pour le moment :
- Les listes
- Taux de mortalité des gens contaminé
- Taux de mortalité par tranche d'age des gens contaminé
- Reffectif
- Taux d'incidence

On peut donc envisager beaucoup d'autres résultats.


'''

NB_REPLICATION = 30
NOM_EXPERIENCE = "configVaccin"
listDptConfig = ["configDpt75"]  

figureNouvCas = plt.figure()
axes = figureNouvCas.add_subplot()

pasFigure = 6 * NB_REPLICATION
compteurFigure = 0
for nbDpt in listDptConfig:

    compteurFigure = compteurFigure + pasFigure
    listResReplication = [[] for x in range(0,NB_REPLICATION)]


    for replication in listResReplication:

        listNumIteration = []
        listNbNouvCas = []
        listNbPersonneHosp = []
        listNbPersonneRea = []
        listNbNouvHosp = []
        listNbNouvRea = []
        listNbNouvMort = []
        nbCasCovidConnuTotal = 0
        listAgeMort = []
        listAgeNouvCasSymptomatique = []
        listReffectif = []
        listTauxIncidence = []
        
        temp = len(listDptConfig) * (listResReplication.index(replication)) + listDptConfig.index(nbDpt)
        stringFormat = f"{temp:04}"
        print(stringFormat)
        print("log-"+NOM_EXPERIENCE+"-"+nbDpt+ "-MRG-NumRepli"+str(listResReplication.index(replication))+".txt")
        f = open("log-"+NOM_EXPERIENCE+"-"+nbDpt+ "-MRG-NumRepli"+str(listResReplication.index(replication))+".txt", "r")
        fileLines = f.readlines()
        i = 0
        #### nbRandomGenere is only available with MT, so I set it to 0 here.
        nbRandomGenere = 0
        for line in fileLines:
            if("CompteurRand:" in line):
                listSplit = line.split(":")
                nbRandomGenere = (int(listSplit[1]))
            elif("NbHumainSimuDepart:" in line):
                listSplit = line.split(":")
                nbHumainSimuDepart = (int(listSplit[1]))
            elif("##" not in line):
                if(i == 0):
                    listNumIteration.append(int(line))
                    i = i + 1
                elif(i==1):
                    listNbNouvCas.append(int(line))
                    i = i + 1
                elif(i==2):
                    listNbPersonneHosp.append(int(line))
                    i = i + 1
                elif(i==3):
                    listNbPersonneRea.append(int(line))
                    i = i + 1
                elif(i==4):
                    listNbNouvHosp.append(int(line))
                    i = i + 1
                elif(i==5):
                    listNbNouvRea.append(int(line))
                    i = i + 1
                elif(i==6):
                    listNbNouvMort.append(int(line))
                    i = i + 1
                elif(i==7):
                    nbCasCovidConnuTotal = (int(line))
                    i = i + 1
                elif(i==8):
                    listReffectif.append(float(line))
                    i = i + 1
                elif(i==9):
                    listTauxIncidence.append(float(line))
                    i = i + 1
                elif("AgeC:" in line):
                    listSplit = line.split(":")
                    listAgeNouvCasSymptomatique.append(int(listSplit[1]))
                elif("AgeD:" in line):
                    listSplit = line.split(":")
                    listAgeMort.append(int(listSplit[1]))

            else:
                i = 0

        f.close()


        #label=str(ville)+ "-MT-"+stringFormat+"config"+NOM_EXPERIENCE+"NumRepli"+str(listResReplication.index(replication)+1) 
        axes.plot(listNumIteration, listNbNouvCas, label="test")
        """
        plt.figure((listResReplication.index(replication)*6)+compteurFigure)
        print("Courbe des nouveaux cas sur la réplication num : " +str(listResReplication.index(replication)))
        plt.plot(listNumIteration, listNbNouvCas)  # Matplotlib plot.
        plt.xlabel("Jour")
        plt.ylabel("Nouv Cas")
        plt.title(label="Courbe nouvCas"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("nouvCas"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        string = "nouvCas"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv"
        with open(string, "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listNbNouvCas)

        plt.figure((listResReplication.index(replication)*6+1)+compteurFigure)
        print("Courbe des nouvelles hospitalisation sur la réplication num : " +str(listResReplication.index(replication)))
        plt.plot(listNumIteration, listNbNouvHosp)
        plt.xlabel("Jour")
        plt.ylabel("Nouv Hosp")
        plt.title(label="Courbe nouvHosp"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("nouvHosp"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("nouvHosp"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listNbNouvHosp)

        plt.figure((listResReplication.index(replication)*6+2)+compteurFigure)
        print("Courbe des nouvelles réanimation sur la réplication num : " +str(listResReplication.index(replication)))
        plt.plot(listNumIteration, listNbNouvRea)
        plt.xlabel("Jour")
        plt.ylabel("Nouv Rea")
        plt.title(label="Courbe nouvRea"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("nouvRea"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("nouvRea"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listNbNouvRea)

        plt.figure((listResReplication.index(replication)*6+3)+compteurFigure)
        print("Courbe des nouveaux morts sur la réplication num : " +str(listResReplication.index(replication)))
        plt.plot(listNumIteration, listNbNouvMort)
        plt.xlabel("Jour")
        plt.ylabel("Nouv Mort")
        plt.title(label="Courbe nouvMort"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("nouvMort"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("nouvMort"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listNbNouvMort)

        print("Courbe de Reffectif sur la réplication num : " +str(listResReplication.index(replication)))
        plt.figure((listResReplication.index(replication)*6+4)+compteurFigure)
        plt.plot(listNumIteration, listReffectif)
        plt.xlabel("Jour")
        plt.ylabel("Reffectif")
        plt.title(label="Courbe Reffectif"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("Reffectif"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("Reffectif"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listReffectif)
            
        print("Courbe du taux d'incidence sur la réplication num : " +str(listResReplication.index(replication)))
        plt.figure((listResReplication.index(replication)*6+5)+compteurFigure)
        plt.plot(listNumIteration, listTauxIncidence)
        plt.xlabel("Jour")
        plt.ylabel("Taux Incidence")
        plt.title(label="Courbe Taux incidence"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("TauxIncidence"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("TauxIncidence"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listTauxIncidence)
        """
        nbMortTotal = sum(listNbNouvMort)
        try:
            tauxDeMortCasConnu = (nbMortTotal / nbCasCovidConnuTotal) * 100
        except:
            tauxDeMortCasConnu = 0
        tauxMortalitePopulationGobale = (nbMortTotal / nbHumainSimuDepart) * 100

        print("Le taux de mort de cas connu est de : " + str(tauxDeMortCasConnu) + "%")
        print("Le taux de mortalité du département sur l'ensemble de la population est de : " + str(tauxMortalitePopulationGobale) + "%")

        ## IL ME FAUT L'AGE DES GENS CONTAMINE AUSSI ... 


        nbAge0 = 0
        nbAge1 = 0
        nbAge2 = 0
        nbAge3 = 0
        nbAge4 = 0
        nbAge5 = 0
        nbAge6 = 0
        nbAge7 = 0

        for i in listAgeNouvCasSymptomatique:
            if i == 0:
                nbAge0 = nbAge0 + 1
            elif i == 1:
                nbAge1 = nbAge1 + 1
            elif i == 2:
                nbAge2 = nbAge2 + 1
            elif i == 3:
                nbAge3 = nbAge3 + 1
            elif i == 4:
                nbAge4 = nbAge4 + 1
            elif i == 5:
                nbAge5 = nbAge5 + 1
            elif i == 6:
                nbAge6 = nbAge6 + 1
            elif i == 7:
                nbAge7 = nbAge7 + 1


        nbAgeMort0 = 0
        nbAgeMort1 = 0
        nbAgeMort2 = 0
        nbAgeMort3 = 0
        nbAgeMort4 = 0
        nbAgeMort5 = 0
        nbAgeMort6 = 0
        nbAgeMort7 = 0

        for i in listAgeMort:
            if i == 0:
                nbAgeMort0 = nbAgeMort0 + 1
            elif i == 1:
                nbAgeMort1 = nbAgeMort1 + 1
            elif i == 2:
                nbAgeMort2 = nbAgeMort2 + 1
            elif i == 3:
                nbAgeMort3 = nbAgeMort3 + 1
            elif i == 4:
                nbAgeMort4 = nbAgeMort4 + 1
            elif i == 5:
                nbAgeMort5 = nbAgeMort5 + 1
            elif i == 6:
                nbAgeMort6 = nbAgeMort6 + 1
            elif i == 7:
                nbAgeMort7 = nbAgeMort7 + 1

        try :
            print("Le taux de mortalité pour les 0 - 15 ans est de : " + str( (nbAgeMort0/nbAge0) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 0 n'a été malade")
        try :
            print("Le taux de mortalité pour les 15 - 25 ans est de : " + str( (nbAgeMort1/nbAge1) * 100) + "%") 
        except ZeroDivisionError:
            print ("Aucun age 1 n'a été malade")
        try :
            print("Le taux de mortalité pour les 25 - 35 ans est de : " + str( (nbAgeMort2/nbAge2) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 2 n'a été malade")
        try:
            print("Le taux de mortalité pour les 35 - 45 ans est de : " + str( (nbAgeMort3/nbAge3) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 3 n'a été malade")
        try :
            print("Le taux de mortalité pour les 45 - 55 ans est de : " + str( (nbAgeMort4/nbAge4) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 4 n'a été malade")
        try:
            print("Le taux de mortalité pour les 55 - 65 ans est de : " + str( (nbAgeMort5/nbAge5) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 5 n'a été malade")
        try:
            print("Le taux de mortalité pour les 65 - 75 ans est de : " + str( (nbAgeMort6/nbAge6) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 6 n'a été malade")
        try:
            print("Le taux de mortalité pour les 75 + ans est de : " + str( (nbAgeMort7/nbAge7) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucune age 7 n'a été malade")

        print("############\n################")
        print(" replication = " + str(listResReplication.index(replication)))
        replication.append(listNumIteration)
        replication.append(listNbNouvCas)
        replication.append(listNbPersonneHosp)
        replication.append(listNbPersonneRea)
        replication.append(listNbNouvHosp)
        replication.append(listNbNouvMort)
        replication.append(listReffectif)
        replication.append(nbCasCovidConnuTotal)
        replication.append(tauxDeMortCasConnu)
        replication.append(tauxMortalitePopulationGobale)
        try :
            replication.append((nbAgeMort0/nbAge0) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort1/nbAge1) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort2/nbAge2) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort3/nbAge3) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort4/nbAge4) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort5/nbAge5) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort6/nbAge6) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort7/nbAge7) * 100)
        except ZeroDivisionError:
            replication.append(0)
            
        replication.append(int(nbRandomGenere))



    dataframeResultats = pd.DataFrame({"Champs":["nbCasCovidConnuTotal","tauxDeMortCasConnu","tauxMortalitePopulationGobale", "tauxDeMort0-15ans", "tauxDeMort15-25ans","tauxDeMort25-35ans","tauxDeMort35-45ans","tauxDeMort45-55ans","tauxDeMort55-65ans","tauxDeMort65-75ans","tauxDeMort75+ans","nbRandomGenere"]})
    numRepli = 1
    listResReplicationTruncated = []
    for replication in listResReplication:
        nomRepli = "R"+str(numRepli)
        dataframeResultats[nomRepli] = replication[-12:]
        listResReplicationTruncated.append(replication[-12:])
        numRepli = numRepli + 1

    
    if(NB_REPLICATION > 1):
        listMoyenne = [mean(list(map(float,list(r)))) for r in zip(*listResReplicationTruncated)]

        listVariance = [variance(list(map(float,list(r)))) for r in zip(*listResReplicationTruncated)]

        '''
        Confidence Intervals Using the t Distribution
        If we’re working with a small sample (n <30), we can use the t.interval() function from the scipy.stats library to calculate a confidence interval for a population mean.

        The following example shows how to calculate a confidence interval for the true population mean height (in inches) of a certain species of plant, using a sample of 15 plants:



        ###########
        Confidence Intervals Using the Normal Distribution
        If we’re working with larger samples (n≥30), we can assume that the sampling distribution of the sample mean is normally distributed (thanks to the Central Limit Theorem) and can instead use the norm.interval() function from the scipy.stats library.




        '''

        listIntervalle95 = [st.t.interval(alpha=0.95, df=len(r)-1, loc=np.mean(r), scale=st.sem(r)) for r in zip(*listResReplicationTruncated)]

        dataframeResultats["Moyenne"] = listMoyenne
        dataframeResultats["Variance"] = listVariance
        dataframeResultats["Intervalle95%"] = listIntervalle95

    print(dataframeResultats)

    dataframeResultats.to_csv("stats"+nbDpt + str(NOM_EXPERIENCE)+".csv", sep="|")
    dataframeResultats.to_html("stats"+nbDpt + str(NOM_EXPERIENCE)+".html",float_format='%.3f')
# Out:
# 0000
# log-configVaccin-configDpt75-MRG-NumRepli0.txt
# Le taux de mort de cas connu est de : 0.7986750840552486%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7979503311824063%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0358010086545047%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07488254310778657%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2738920582467187%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4303379470245205%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1488485878354624%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7007573105796987%
# Le taux de mortalité pour les 75 + ans est de : 3.7712322852027773%
# ############
# ################
#  replication = 0
# 0001
# log-configVaccin-configDpt75-MRG-NumRepli1.txt
# Le taux de mort de cas connu est de : 0.7998195402251033%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7990586596706509%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03774010683951895%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08058569684466704%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.26035449988063974%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4192813517630781%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.0929443715569864%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7065141352207727%
# Le taux de mortalité pour les 75 + ans est de : 3.88089580812719%
# ############
# ################
#  replication = 1
# 0002
# log-configVaccin-configDpt75-MRG-NumRepli2.txt
# Le taux de mort de cas connu est de : 0.8001534667538777%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.799381922146389%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03801927344392545%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07594570484847023%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.266553808229756%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4263019183586326%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1113598743297157%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.701440379364614%
# Le taux de mortalité pour les 75 + ans est de : 3.8578334912421353%
# ############
# ################
#  replication = 2
# 0003
# log-configVaccin-configDpt75-MRG-NumRepli3.txt
# Le taux de mort de cas connu est de : 0.8045217775563154%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8037690557456904%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.035368237767836666%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0712574729765092%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2648858795736528%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4362531248468212%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1196306615598375%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7607566260486343%
# Le taux de mortalité pour les 75 + ans est de : 3.8127644723640013%
# ############
# ################
#  replication = 3
# 0004
# log-configVaccin-configDpt75-MRG-NumRepli4.txt
# Le taux de mort de cas connu est de : 0.8068124460353177%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8060780734295331%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04578150582356273%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08288055990422691%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2699773963752276%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4091199360004491%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.189833929718323%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7023336242951759%
# Le taux de mortalité pour les 75 + ans est de : 3.8405878311544663%
# ############
# ################
#  replication = 4
# 0005
# log-configVaccin-configDpt75-MRG-NumRepli5.txt
# Le taux de mort de cas connu est de : 0.8034989158334539%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8027530879647995%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.05053057099545225%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07117809805687814%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.28113872368985254%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.42476622073813214%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1431273089778924%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7176046199923882%
# Le taux de mortalité pour les 75 + ans est de : 3.8064350114338703%
# ############
# ################
#  replication = 5
# 0006
# log-configVaccin-configDpt75-MRG-NumRepli6.txt
# Le taux de mort de cas connu est de : 0.8070935111733987%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8063551555515943%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.040041051796793604%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08211238125905651%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.27620288221440065%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.42414172643209175%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1277190335092608%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.731115479277821%
# Le taux de mortalité pour les 75 + ans est de : 3.84732898469895%
# ############
# ################
#  replication = 6
# 0007
# log-configVaccin-configDpt75-MRG-NumRepli7.txt
# Le taux de mort de cas connu est de : 0.8027275912532923%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8019680219522929%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.038392330841063506%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07694011963987189%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2512310320570797%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.42556467813171506%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.173309416249159%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7551760753965466%
# Le taux de mortalité pour les 75 + ans est de : 3.760749333553459%
# ############
# ################
#  replication = 7
# 0008
# log-configVaccin-configDpt75-MRG-NumRepli8.txt
# Le taux de mort de cas connu est de : 0.8107705833572928%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8100034034920659%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04202988792029888%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.06731753722619499%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.26901051078463883%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4018784588257887%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1679207193980548%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7384812726590309%
# Le taux de mortalité pour les 75 + ans est de : 3.895116853505605%
# ############
# ################
#  replication = 8
# 0009
# log-configVaccin-configDpt75-MRG-NumRepli9.txt
# Le taux de mort de cas connu est de : 0.8012839031840114%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8005364309883104%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04572721777006185%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08187247158543634%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.262349819634499%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4192806027552725%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1420573930675757%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7483341812361182%
# Le taux de mortalité pour les 75 + ans est de : 3.787056021740507%
# ############
# ################
#  replication = 9
# 0010
# log-configVaccin-configDpt75-MRG-NumRepli10.txt
# Le taux de mort de cas connu est de : 0.8089141413907961%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8081561893449918%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03772807007308355%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.06760998696093108%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2608776670082922%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.41330687424011625%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1837834864403982%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.763642964405353%
# Le taux de mortalité pour les 75 + ans est de : 3.811452324068139%
# ############
# ################
#  replication = 10
# 0011
# log-configVaccin-configDpt75-MRG-NumRepli11.txt
# Le taux de mort de cas connu est de : 0.8000587979426268%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7992895614390353%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03884189020174478%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07702583976218272%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.26921870565919376%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.40156006785945403%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1945210712488477%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.6826853933045969%
# Le taux de mortalité pour les 75 + ans est de : 3.8032639806521136%
# ############
# ################
#  replication = 11
# 0012
# log-configVaccin-configDpt75-MRG-NumRepli12.txt
# Le taux de mort de cas connu est de : 0.7915920957269001%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7908847370698474%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04545613482988915%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07481206485321149%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2524678075576257%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4228352102577081%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.101485103255086%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.6899574832734583%
# Le taux de mortalité pour les 75 + ans est de : 3.810529697211582%
# ############
# ################
#  replication = 12
# 0013
# log-configVaccin-configDpt75-MRG-NumRepli13.txt
# Le taux de mort de cas connu est de : 0.8036021344338314%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8028454486721532%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.039976247123068624%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07796894906698498%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2657264992303994%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.41920292008572857%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.148074854333643%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.6879854665237597%
# Le taux de mortalité pour les 75 + ans est de : 3.875987841945289%
# ############
# ################
#  replication = 13
# 0014
# log-configVaccin-configDpt75-MRG-NumRepli14.txt
# Le taux de mort de cas connu est de : 0.803960405192716%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8032148915015681%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03961241965863415%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07599578605376801%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.26194690265486725%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4260742006294835%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.159203102961918%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.723403110815027%
# Le taux de mortalité pour les 75 + ans est de : 3.8134462668393656%
# ############
# ################
#  replication = 14
# 0015
# log-configVaccin-configDpt75-MRG-NumRepli15.txt
# Le taux de mort de cas connu est de : 0.7978933618433915%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7971652651698998%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0337954636388003%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08865605480556116%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2703658877199516%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.409531683529049%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1538052077253187%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.712882060074516%
# Le taux de mortalité pour les 75 + ans est de : 3.7584081124665247%
# ############
# ################
#  replication = 15
# 0016
# log-configVaccin-configDpt75-MRG-NumRepli16.txt
# Le taux de mort de cas connu est de : 0.7941981289058166%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7934708368757513%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03693221577744258%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07405022537025112%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2710087714393287%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4060087904568734%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1669392818328521%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7001807734788346%
# Le taux de mortalité pour les 75 + ans est de : 3.7530042521723055%
# ############
# ################
#  replication = 16
# 0017
# log-configVaccin-configDpt75-MRG-NumRepli17.txt
# Le taux de mort de cas connu est de : 0.8015553159143004%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8008135131103714%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03383291981986887%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0745201506515478%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2686359182243948%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4132708990743432%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1495638451759962%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.718719673600185%
# Le taux de mortalité pour les 75 + ans est de : 3.819294264011935%
# ############
# ################
#  replication = 17
# 0018
# log-configVaccin-configDpt75-MRG-NumRepli18.txt
# Le taux de mort de cas connu est de : 0.8042713278658291%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8035381539773061%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.039999378650428734%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07944755859257446%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2661545717943535%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.42413295554988806%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1356797933393024%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7111553291445463%
# Le taux de mortalité pour les 75 + ans est de : 3.8448864076917113%
# ############
# ################
#  replication = 18
# 0019
# log-configVaccin-configDpt75-MRG-NumRepli19.txt
# Le taux de mort de cas connu est de : 0.8042093643843139%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8034457932699524%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.039225890641323896%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07119012186783573%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.27938892055296655%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4105974576418879%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1663825572790296%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7310737453126228%
# Le taux de mortalité pour les 75 + ans est de : 3.8197033722760794%
# ############
# ################
#  replication = 19
# 0020
# log-configVaccin-configDpt75-MRG-NumRepli20.txt
# Le taux de mort de cas connu est de : 0.8055197074299913%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8047850235265812%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03341362965265366%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07718686054505179%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2506209665106337%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4233611375468846%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1488559141678776%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7210643217285924%
# Le taux de mortalité pour les 75 + ans est de : 3.873261671030198%
# ############
# ################
#  replication = 20
# 0021
# log-configVaccin-configDpt75-MRG-NumRepli21.txt
# Le taux de mort de cas connu est de : 0.8000928179778438%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7993357417927122%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.038905661551869024%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0788145646098478%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2587008216457553%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.41329984904047884%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1473639907039728%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.6978012690219295%
# Le taux de mortalité pour les 75 + ans est de : 3.8455724963796913%
# ############
# ################
#  replication = 21
# 0022
# log-configVaccin-configDpt75-MRG-NumRepli22.txt
# Le taux de mort de cas connu est de : 0.8070711637078679%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8063089751979174%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03698714404740584%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07957016038611621%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.27379706236240303%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4445657002346999%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.140552910617444%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7026092682525311%
# Le taux de mortalité pour les 75 + ans est de : 3.858101331152074%
# ############
# ################
#  replication = 22
# 0023
# log-configVaccin-configDpt75-MRG-NumRepli23.txt
# Le taux de mort de cas connu est de : 0.8043164350306824%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.803584334330983%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.037777881634497044%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07139562400978682%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2582191067256031%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4297828668303601%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1324485125858124%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7507442937479325%
# Le taux de mortalité pour les 75 + ans est de : 3.827969737756377%
# ############
# ################
#  replication = 23
# 0024
# log-configVaccin-configDpt75-MRG-NumRepli24.txt
# Le taux de mort de cas connu est de : 0.8009359043277255%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8002131685125724%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03661662394727206%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0760447094609275%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.25023623047130317%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.3954536849412078%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.136891545375068%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7498598793313773%
# Le taux de mortalité pour les 75 + ans est de : 3.847672531040232%
# ############
# ################
#  replication = 24
# 0025
# log-configVaccin-configDpt75-MRG-NumRepli25.txt
# Le taux de mort de cas connu est de : 0.8103278198992105%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8095415999552975%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.036876305227119224%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.06729555969476657%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2629053279407865%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.419191689069121%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1394128940133104%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7513149277767939%
# Le taux de mortalité pour les 75 + ans est de : 3.8881177258563953%
# ############
# ################
#  replication = 25
# 0026
# log-configVaccin-configDpt75-MRG-NumRepli26.txt
# Le taux de mort de cas connu est de : 0.8060728872191294%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8053391877707033%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.034243643523670916%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08005760929472867%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2842420521978533%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.42465815717948624%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1418602515838765%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.6993998233317646%
# Le taux de mortalité pour les 75 + ans est de : 3.858627051170017%
# ############
# ################
#  replication = 26
# 0027
# log-configVaccin-configDpt75-MRG-NumRepli27.txt
# Le taux de mort de cas connu est de : 0.7982305711816068%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7974885276456378%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03941401890311956%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07416672680185056%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2591214477991455%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.43061967391455946%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1374923664402963%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.6879340313532305%
# Le taux de mortalité pour les 75 + ans est de : 3.82674291276311%
# ############
# ################
#  replication = 27
# 0028
# log-configVaccin-configDpt75-MRG-NumRepli28.txt
# Le taux de mort de cas connu est de : 0.7972646721799096%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7965187402184237%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04862053809321919%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08205458238642077%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.25461015611622734%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.39009563295992944%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.156046051184278%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.6610091289589033%
# Le taux de mortalité pour les 75 + ans est de : 3.8690490700338835%
# ############
# ################
#  replication = 28
# 0029
# log-configVaccin-configDpt75-MRG-NumRepli29.txt
# Le taux de mort de cas connu est de : 0.8055741217864627%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8048312038802581%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04221942480875375%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.06988878044078131%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.28533596911657744%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.44305419514746824%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1907298685457737%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.689119512939604%
# Le taux de mortalité pour les 75 + ans est de : 3.783252955818295%
# ############
# ################
#  replication = 29
#                            Champs            R1            R2            R3  \
# 0            nbCasCovidConnuTotal  2.163458e+06  2.163363e+06  2.163335e+06
# 1              tauxDeMortCasConnu  7.986751e-01  7.998195e-01  8.001535e-01
# 2   tauxMortalitePopulationGobale  7.979503e-01  7.990587e-01  7.993819e-01
# 3               tauxDeMort0-15ans  0.000000e+00  0.000000e+00  0.000000e+00
# 4              tauxDeMort15-25ans  3.580101e-02  3.774011e-02  3.801927e-02
# 5              tauxDeMort25-35ans  7.488254e-02  8.058570e-02  7.594570e-02
# 6              tauxDeMort35-45ans  2.738921e-01  2.603545e-01  2.665538e-01
# 7              tauxDeMort45-55ans  4.303379e-01  4.192814e-01  4.263019e-01
# 8              tauxDeMort55-65ans  1.148849e+00  1.092944e+00  1.111360e+00
# 9              tauxDeMort65-75ans  1.700757e+00  1.706514e+00  1.701440e+00
# 10               tauxDeMort75+ans  3.771232e+00  3.880896e+00  3.857833e+00
# 11                 nbRandomGenere  0.000000e+00  0.000000e+00  0.000000e+00
#
#               R4            R5            R6            R7            R8  \
# 0   2.163397e+06  2.163452e+06  2.163413e+06  2.163442e+06  2.163374e+06
# 1   8.045218e-01  8.068124e-01  8.034989e-01  8.070935e-01  8.027276e-01
# 2   8.037691e-01  8.060781e-01  8.027531e-01  8.063552e-01  8.019680e-01
# 3   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 4   3.536824e-02  4.578151e-02  5.053057e-02  4.004105e-02  3.839233e-02
# 5   7.125747e-02  8.288056e-02  7.117810e-02  8.211238e-02  7.694012e-02
# 6   2.648859e-01  2.699774e-01  2.811387e-01  2.762029e-01  2.512310e-01
# 7   4.362531e-01  4.091199e-01  4.247662e-01  4.241417e-01  4.255647e-01
# 8   1.119631e+00  1.189834e+00  1.143127e+00  1.127719e+00  1.173309e+00
# 9   1.760757e+00  1.702334e+00  1.717605e+00  1.731115e+00  1.755176e+00
# 10  3.812764e+00  3.840588e+00  3.806435e+00  3.847329e+00  3.760749e+00
# 11  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#               R9  ...           R24           R25           R26           R27  \
# 0   2.163374e+06  ...  2.163452e+06  2.163469e+06  2.163322e+06  2.163452e+06
# 1   8.107706e-01  ...  8.043164e-01  8.009359e-01  8.103278e-01  8.060729e-01
# 2   8.100034e-01  ...  8.035843e-01  8.002132e-01  8.095416e-01  8.053392e-01
# 3   0.000000e+00  ...  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 4   4.202989e-02  ...  3.777788e-02  3.661662e-02  3.687631e-02  3.424364e-02
# 5   6.731754e-02  ...  7.139562e-02  7.604471e-02  6.729556e-02  8.005761e-02
# 6   2.690105e-01  ...  2.582191e-01  2.502362e-01  2.629053e-01  2.842421e-01
# 7   4.018785e-01  ...  4.297829e-01  3.954537e-01  4.191917e-01  4.246582e-01
# 8   1.167921e+00  ...  1.132449e+00  1.136892e+00  1.139413e+00  1.141860e+00
# 9   1.738481e+00  ...  1.750744e+00  1.749860e+00  1.751315e+00  1.699400e+00
# 10  3.895117e+00  ...  3.827970e+00  3.847673e+00  3.888118e+00  3.858627e+00
# 11  0.000000e+00  ...  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#              R28           R29           R30       Moyenne     Variance  \
# 0   2.163410e+06  2.163397e+06  2.163426e+06  2.163409e+06  1799.978161
# 1   7.982306e-01  7.972647e-01  8.055741e-01  8.027006e-01     0.000020
# 2   7.974885e-01  7.965187e-01  8.048312e-01  8.019542e-01     0.000020
# 3   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00     0.000000
# 4   3.941402e-02  4.862054e-02  4.221942e-02  3.933022e-02     0.000018
# 5   7.416673e-02  8.205458e-02  6.988878e-02  7.609082e-02     0.000026
# 6   2.591214e-01  2.546102e-01  2.853360e-01  2.659726e-01     0.000093
# 7   4.306197e-01  3.900956e-01  4.430542e-01  4.192510e-01     0.000163
# 8   1.137492e+00  1.156046e+00  1.190730e+00  1.148261e+00     0.000606
# 9   1.687934e+00  1.661009e+00  1.689120e+00  1.716502e+00     0.000703
# 10  3.826743e+00  3.869049e+00  3.783253e+00  3.828278e+00     0.001563
# 11  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00     0.000000
#
#                                  Intervalle95%
# 0     (2163393.5911487527, 2163425.2755179135)
# 1     (0.8010335058982133, 0.8043676936863379)
# 2     (0.8002902022296772, 0.8036181334627028)
# 3                                   (nan, nan)
# 4   (0.0377279451562743, 0.040932501087517933)
# 5   (0.07418677370645187, 0.07799485969782978)
# 6     (0.2623663828006993, 0.2695787774269092)
# 7     (0.414488272512559, 0.42401370155845636)
# 8     (1.1390657434679978, 1.1574571835328267)
# 9     (1.7065991962469924, 1.7264045477827652)
# 10     (3.813514214932627, 3.8430420580912577)
# 11                                  (nan, nan)
#
# [12 rows x 34 columns]
# /tmp/ipykernel_121077/1526652622.py:362: DeprecationWarning: Use of keyword argument 'alpha' for method 'interval' is deprecated and wil be removed in SciPy 1.11.0. Use first positional argument or keyword argument 'confidence' instead.
#   listIntervalle95 = [st.t.interval(alpha=0.95, df=len(r)-1, loc=np.mean(r), scale=st.sem(r)) for r in zip(*listResReplicationTruncated)]
# /usr/lib/python3/dist-packages/scipy/stats/_distn_infrastructure.py:2351: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /usr/lib/python3/dist-packages/scipy/stats/_distn_infrastructure.py:2352: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
import matplotlib.pyplot as plt
plt.plot([44,221,588,917,1990],[70000,161000,264000,330000,492000])

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

x = np.array([44,221,588,917,1990]).reshape(-1,1)
y = np.array([70000,161000,264000,330000,492000])

model = LinearRegression()
model.fit(np.log(x),y)

x_pred = np.array([50,100,220,500,1000,1500,3000,5000,8000,12000]).reshape(-1,1)
y_pred = model.predict(np.log(x_pred))
print(y_pred)

plt.plot([44,221,588,917,1990],[70000,161000,264000,330000,492000],color='r')
plt.plot([50,100,220,500,1000,1500,3000,5000,8000,12000],y_pred)
# Out:
# [ 43885.06248518 116924.96278337 200008.1067469  286518.35933351
#  359558.2596317  402283.86236256 475323.76266075 529151.65618184
#  578677.96052628 621403.56325713]
