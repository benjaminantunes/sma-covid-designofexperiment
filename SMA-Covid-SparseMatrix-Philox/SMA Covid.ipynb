# %%
# !make clean
# !make
# Out:
# rm -rf *.o
# rm -rf *.d
# g++ -o City.o -c City.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o Human.o -c Human.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o main.o -c main.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o Position.o -c Position.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o RandomGenerator.o -c RandomGenerator.cpp -MMD -O2 -std=c++11 -fPIE
# RandomGenerator.cpp: In constructor ‘RandomGenerator::RandomGenerator(int)’:
# RandomGenerator.cpp:7:13: warning: narrowing conversion of ‘seed’ from ‘int’ to ‘uint32_t’ {aka ‘unsigned int’} [-Wnarrowing]
#     7 |     key = {{seed}};
#       |             ^~~~
# g++ -o SimulationParams.o -c SimulationParams.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -o World.o -c World.cpp -MMD -O2 -std=c++11 -fPIE
# g++ -O2 City.o Human.o main.o Position.o RandomGenerator.o SimulationParams.o World.o  -o exe

# %%
# !./replicationSimulation.sh 1 configToyEpidemicalContext configToyState
# Out:
# mts000M000000 0 configToyEpidemicalContext configToyState
# Nom de la commande :./exe
# Nom du fichier MT a utiliser :mts000M000000
# Num�ro de la replication :0
# config �pid�mie :configToyEpidemicalContext
# config g�ographique :configToyState
# log file name : log-configToyEpidemicalContext-configToyState-Philox-NumRepli0.txt
# 1000 1000
# 1000 1000
# La ville a pour coord X : 500 , coordY : 0, taille : 500 , nbHab : 10000
# Le pourcentage de carte recouverte par des lieu est de : 0.000000 %
# ***************STATISTICS******************
# Safe : 1411
# Contamined : 508
# Recovered : 96608
# Dead : 1473
#
# real	1m16,483s
# user	1m16,353s
# sys	0m0,108s

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st
import pandas as pd
import csv
from statistics import mean,variance
'''
Ce qu'on a comme résultats pour le moment :
- Les listes
- Taux de mortalité des gens contaminé
- Taux de mortalité par tranche d'age des gens contaminé
- Reffectif
- Taux d'incidence

On peut donc envisager beaucoup d'autres résultats.


'''

NB_REPLICATION = 30
NOM_EXPERIENCE = "configVaccin"
listDptConfig = ["configDpt75"]  

figureNouvCas = plt.figure()
axes = figureNouvCas.add_subplot()

pasFigure = 6 * NB_REPLICATION
compteurFigure = 0
for nbDpt in listDptConfig:

    compteurFigure = compteurFigure + pasFigure
    listResReplication = [[] for x in range(0,NB_REPLICATION)]


    for replication in listResReplication:

        listNumIteration = []
        listNbNouvCas = []
        listNbPersonneHosp = []
        listNbPersonneRea = []
        listNbNouvHosp = []
        listNbNouvRea = []
        listNbNouvMort = []
        nbCasCovidConnuTotal = 0
        listAgeMort = []
        listAgeNouvCasSymptomatique = []
        listReffectif = []
        listTauxIncidence = []
        
        temp = len(listDptConfig) * (listResReplication.index(replication)) + listDptConfig.index(nbDpt)
        stringFormat = f"{temp:04}"
        print(stringFormat)
        print("log-"+NOM_EXPERIENCE+"-"+nbDpt+ "-Philox-NumRepli"+str(listResReplication.index(replication))+".txt")
        f = open("log-"+NOM_EXPERIENCE+"-"+nbDpt+ "-Philox-NumRepli"+str(listResReplication.index(replication))+".txt", "r")
        fileLines = f.readlines()
        i = 0
        #### nbRandomGenere is only available with MT, so I set it to 0 here.
        nbRandomGenere = 0
        for line in fileLines:
            if("CompteurRand:" in line):
                listSplit = line.split(":")
                nbRandomGenere = (int(listSplit[1]))
            elif("NbHumainSimuDepart:" in line):
                listSplit = line.split(":")
                nbHumainSimuDepart = (int(listSplit[1]))
            elif("##" not in line):
                if(i == 0):
                    listNumIteration.append(int(line))
                    i = i + 1
                elif(i==1):
                    listNbNouvCas.append(int(line))
                    i = i + 1
                elif(i==2):
                    listNbPersonneHosp.append(int(line))
                    i = i + 1
                elif(i==3):
                    listNbPersonneRea.append(int(line))
                    i = i + 1
                elif(i==4):
                    listNbNouvHosp.append(int(line))
                    i = i + 1
                elif(i==5):
                    listNbNouvRea.append(int(line))
                    i = i + 1
                elif(i==6):
                    listNbNouvMort.append(int(line))
                    i = i + 1
                elif(i==7):
                    nbCasCovidConnuTotal = (int(line))
                    i = i + 1
                elif(i==8):
                    listReffectif.append(float(line))
                    i = i + 1
                elif(i==9):
                    listTauxIncidence.append(float(line))
                    i = i + 1
                elif("AgeC:" in line):
                    listSplit = line.split(":")
                    listAgeNouvCasSymptomatique.append(int(listSplit[1]))
                elif("AgeD:" in line):
                    listSplit = line.split(":")
                    listAgeMort.append(int(listSplit[1]))

            else:
                i = 0

        f.close()


        #label=str(ville)+ "-MT-"+stringFormat+"config"+NOM_EXPERIENCE+"NumRepli"+str(listResReplication.index(replication)+1) 
        axes.plot(listNumIteration, listNbNouvCas, label="test")
        """
        plt.figure((listResReplication.index(replication)*6)+compteurFigure)
        print("Courbe des nouveaux cas sur la réplication num : " +str(listResReplication.index(replication)))
        plt.plot(listNumIteration, listNbNouvCas)  # Matplotlib plot.
        plt.xlabel("Jour")
        plt.ylabel("Nouv Cas")
        plt.title(label="Courbe nouvCas"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("nouvCas"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        string = "nouvCas"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv"
        with open(string, "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listNbNouvCas)

        plt.figure((listResReplication.index(replication)*6+1)+compteurFigure)
        print("Courbe des nouvelles hospitalisation sur la réplication num : " +str(listResReplication.index(replication)))
        plt.plot(listNumIteration, listNbNouvHosp)
        plt.xlabel("Jour")
        plt.ylabel("Nouv Hosp")
        plt.title(label="Courbe nouvHosp"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("nouvHosp"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("nouvHosp"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listNbNouvHosp)

        plt.figure((listResReplication.index(replication)*6+2)+compteurFigure)
        print("Courbe des nouvelles réanimation sur la réplication num : " +str(listResReplication.index(replication)))
        plt.plot(listNumIteration, listNbNouvRea)
        plt.xlabel("Jour")
        plt.ylabel("Nouv Rea")
        plt.title(label="Courbe nouvRea"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("nouvRea"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("nouvRea"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listNbNouvRea)

        plt.figure((listResReplication.index(replication)*6+3)+compteurFigure)
        print("Courbe des nouveaux morts sur la réplication num : " +str(listResReplication.index(replication)))
        plt.plot(listNumIteration, listNbNouvMort)
        plt.xlabel("Jour")
        plt.ylabel("Nouv Mort")
        plt.title(label="Courbe nouvMort"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("nouvMort"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("nouvMort"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listNbNouvMort)

        print("Courbe de Reffectif sur la réplication num : " +str(listResReplication.index(replication)))
        plt.figure((listResReplication.index(replication)*6+4)+compteurFigure)
        plt.plot(listNumIteration, listReffectif)
        plt.xlabel("Jour")
        plt.ylabel("Reffectif")
        plt.title(label="Courbe Reffectif"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("Reffectif"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("Reffectif"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listReffectif)
            
        print("Courbe du taux d'incidence sur la réplication num : " +str(listResReplication.index(replication)))
        plt.figure((listResReplication.index(replication)*6+5)+compteurFigure)
        plt.plot(listNumIteration, listTauxIncidence)
        plt.xlabel("Jour")
        plt.ylabel("Taux Incidence")
        plt.title(label="Courbe Taux incidence"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication)))
        plt.savefig("TauxIncidence"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".png")
        with open("TauxIncidence"+str(ville) + str(NOM_EXPERIENCE)+"_replication"+str(listResReplication.index(replication))+".csv", "w") as fCsv:
            write = csv.writer(fCsv)
            write.writerow(listTauxIncidence)
        """
        nbMortTotal = sum(listNbNouvMort)
        try:
            tauxDeMortCasConnu = (nbMortTotal / nbCasCovidConnuTotal) * 100
        except:
            tauxDeMortCasConnu = 0
        tauxMortalitePopulationGobale = (nbMortTotal / nbHumainSimuDepart) * 100

        print("Le taux de mort de cas connu est de : " + str(tauxDeMortCasConnu) + "%")
        print("Le taux de mortalité du département sur l'ensemble de la population est de : " + str(tauxMortalitePopulationGobale) + "%")

        ## IL ME FAUT L'AGE DES GENS CONTAMINE AUSSI ... 


        nbAge0 = 0
        nbAge1 = 0
        nbAge2 = 0
        nbAge3 = 0
        nbAge4 = 0
        nbAge5 = 0
        nbAge6 = 0
        nbAge7 = 0

        for i in listAgeNouvCasSymptomatique:
            if i == 0:
                nbAge0 = nbAge0 + 1
            elif i == 1:
                nbAge1 = nbAge1 + 1
            elif i == 2:
                nbAge2 = nbAge2 + 1
            elif i == 3:
                nbAge3 = nbAge3 + 1
            elif i == 4:
                nbAge4 = nbAge4 + 1
            elif i == 5:
                nbAge5 = nbAge5 + 1
            elif i == 6:
                nbAge6 = nbAge6 + 1
            elif i == 7:
                nbAge7 = nbAge7 + 1


        nbAgeMort0 = 0
        nbAgeMort1 = 0
        nbAgeMort2 = 0
        nbAgeMort3 = 0
        nbAgeMort4 = 0
        nbAgeMort5 = 0
        nbAgeMort6 = 0
        nbAgeMort7 = 0

        for i in listAgeMort:
            if i == 0:
                nbAgeMort0 = nbAgeMort0 + 1
            elif i == 1:
                nbAgeMort1 = nbAgeMort1 + 1
            elif i == 2:
                nbAgeMort2 = nbAgeMort2 + 1
            elif i == 3:
                nbAgeMort3 = nbAgeMort3 + 1
            elif i == 4:
                nbAgeMort4 = nbAgeMort4 + 1
            elif i == 5:
                nbAgeMort5 = nbAgeMort5 + 1
            elif i == 6:
                nbAgeMort6 = nbAgeMort6 + 1
            elif i == 7:
                nbAgeMort7 = nbAgeMort7 + 1

        try :
            print("Le taux de mortalité pour les 0 - 15 ans est de : " + str( (nbAgeMort0/nbAge0) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 0 n'a été malade")
        try :
            print("Le taux de mortalité pour les 15 - 25 ans est de : " + str( (nbAgeMort1/nbAge1) * 100) + "%") 
        except ZeroDivisionError:
            print ("Aucun age 1 n'a été malade")
        try :
            print("Le taux de mortalité pour les 25 - 35 ans est de : " + str( (nbAgeMort2/nbAge2) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 2 n'a été malade")
        try:
            print("Le taux de mortalité pour les 35 - 45 ans est de : " + str( (nbAgeMort3/nbAge3) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 3 n'a été malade")
        try :
            print("Le taux de mortalité pour les 45 - 55 ans est de : " + str( (nbAgeMort4/nbAge4) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 4 n'a été malade")
        try:
            print("Le taux de mortalité pour les 55 - 65 ans est de : " + str( (nbAgeMort5/nbAge5) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 5 n'a été malade")
        try:
            print("Le taux de mortalité pour les 65 - 75 ans est de : " + str( (nbAgeMort6/nbAge6) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucun age 6 n'a été malade")
        try:
            print("Le taux de mortalité pour les 75 + ans est de : " + str( (nbAgeMort7/nbAge7) * 100) + "%")
        except ZeroDivisionError:
            print ("Aucune age 7 n'a été malade")

        print("############\n################")
        print(" replication = " + str(listResReplication.index(replication)))
        replication.append(listNumIteration)
        replication.append(listNbNouvCas)
        replication.append(listNbPersonneHosp)
        replication.append(listNbPersonneRea)
        replication.append(listNbNouvHosp)
        replication.append(listNbNouvMort)
        replication.append(listReffectif)
        replication.append(nbCasCovidConnuTotal)
        replication.append(tauxDeMortCasConnu)
        replication.append(tauxMortalitePopulationGobale)
        try :
            replication.append((nbAgeMort0/nbAge0) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort1/nbAge1) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort2/nbAge2) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort3/nbAge3) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort4/nbAge4) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort5/nbAge5) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort6/nbAge6) * 100)
        except ZeroDivisionError:
            replication.append(0)
        try :
            replication.append((nbAgeMort7/nbAge7) * 100)
        except ZeroDivisionError:
            replication.append(0)
            
        replication.append(int(nbRandomGenere))



    dataframeResultats = pd.DataFrame({"Champs":["nbCasCovidConnuTotal","tauxDeMortCasConnu","tauxMortalitePopulationGobale", "tauxDeMort0-15ans", "tauxDeMort15-25ans","tauxDeMort25-35ans","tauxDeMort35-45ans","tauxDeMort45-55ans","tauxDeMort55-65ans","tauxDeMort65-75ans","tauxDeMort75+ans","nbRandomGenere"]})
    numRepli = 1
    listResReplicationTruncated = []
    for replication in listResReplication:
        nomRepli = "R"+str(numRepli)
        dataframeResultats[nomRepli] = replication[-12:]
        listResReplicationTruncated.append(replication[-12:])
        numRepli = numRepli + 1

    
    if(NB_REPLICATION > 1):
        listMoyenne = [mean(list(map(float,list(r)))) for r in zip(*listResReplicationTruncated)]

        listVariance = [variance(list(map(float,list(r)))) for r in zip(*listResReplicationTruncated)]

        '''
        Confidence Intervals Using the t Distribution
        If we’re working with a small sample (n <30), we can use the t.interval() function from the scipy.stats library to calculate a confidence interval for a population mean.

        The following example shows how to calculate a confidence interval for the true population mean height (in inches) of a certain species of plant, using a sample of 15 plants:



        ###########
        Confidence Intervals Using the Normal Distribution
        If we’re working with larger samples (n≥30), we can assume that the sampling distribution of the sample mean is normally distributed (thanks to the Central Limit Theorem) and can instead use the norm.interval() function from the scipy.stats library.




        '''

        listIntervalle95 = [st.t.interval(alpha=0.95, df=len(r)-1, loc=np.mean(r), scale=st.sem(r)) for r in zip(*listResReplicationTruncated)]

        dataframeResultats["Moyenne"] = listMoyenne
        dataframeResultats["Variance"] = listVariance
        dataframeResultats["Intervalle95%"] = listIntervalle95

    print(dataframeResultats)

    dataframeResultats.to_csv("stats"+nbDpt + str(NOM_EXPERIENCE)+".csv", sep="|")
    dataframeResultats.to_html("stats"+nbDpt + str(NOM_EXPERIENCE)+".html",float_format='%.3f')
# Out:
# 0000
# log-configVaccin-configDpt75-Philox-NumRepli0.txt
# Le taux de mort de cas connu est de : 0.8041165442032977%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8033534325625986%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04111092581029247%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0777091503531136%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2629086271321703%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.43153503678573063%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1435724984581044%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7430949959905093%
# Le taux de mortalité pour les 75 + ans est de : 3.810422942347279%
# ############
# ################
#  replication = 0
# 0001
# log-configVaccin-configDpt75-Philox-NumRepli1.txt
# Le taux de mort de cas connu est de : 0.8043637728460435%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8036305146846598%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04201713365338977%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07483223096605997%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.27058959460013493%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.43975127443840684%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1613503767334135%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7114299957564447%
# Le taux de mortalité pour les 75 + ans est de : 3.8071771852357834%
# ############
# ################
#  replication = 1
# 0002
# log-configVaccin-configDpt75-Philox-NumRepli2.txt
# Le taux de mort de cas connu est de : 0.8058600270037529%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8051082860023193%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03880119818099983%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07408123168099977%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.27297848616275033%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.42195126218008155%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.152686842366762%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.6970637906046255%
# Le taux de mortalité pour les 75 + ans est de : 3.8719017498858346%
# ############
# ################
#  replication = 2
# 0003
# log-configVaccin-configDpt75-Philox-NumRepli3.txt
# Le taux de mort de cas connu est de : 0.7963243722959731%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7955951331448867%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0410512210801893%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07340053024863928%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.26880114688489337%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4069478560881219%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1504854012184635%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7284501825187168%
# Le taux de mortalité pour les 75 + ans est de : 3.7720041694674187%
# ############
# ################
#  replication = 3
# 0004
# log-configVaccin-configDpt75-Philox-NumRepli4.txt
# Le taux de mort de cas connu est de : 0.8100946127275358%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.80935687854059%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03875818766714468%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.06854366752713688%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.27456174290901514%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4309164085382557%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.2114978418587565%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7383144344173855%
# Le taux de mortalité pour les 75 + ans est de : 3.7907332223423005%
# ############
# ################
#  replication = 4
# 0005
# log-configVaccin-configDpt75-Philox-NumRepli5.txt
# Le taux de mort de cas connu est de : 0.8047543835077584%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8039999575140746%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03347918840218627%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.06639491696611445%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.26421947334732576%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4033869079745141%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1242036585990243%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7492288902229491%
# Le taux de mortalité pour les 75 + ans est de : 3.8928741763108463%
# ############
# ################
#  replication = 5
# 0006
# log-configVaccin-configDpt75-Philox-NumRepli6.txt
# Le taux de mort de cas connu est de : 0.8124812503437918%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8117120765781096%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.037697865212643164%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08181796305357472%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2835897550409754%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.41772764578379173%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1611643214549245%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7660107865613301%
# Le taux de mortalité pour les 75 + ans est de : 3.8369362962385654%
# ############
# ################
#  replication = 6
# 0007
# log-configVaccin-configDpt75-Philox-NumRepli7.txt
# Le taux de mort de cas connu est de : 0.8176409655272511%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8168842761899177%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.032230506368437405%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07632361211536916%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2641104855971998%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.424645489057615%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1921074770303484%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7488554556955245%
# Le taux de mortalité pour les 75 + ans est de : 3.8875935101525307%
# ############
# ################
#  replication = 7
# 0008
# log-configVaccin-configDpt75-Philox-NumRepli8.txt
# Le taux de mort de cas connu est de : 0.812583488562356%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8118506176391402%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03372602835312315%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08540500908435356%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2753111647780048%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.42162889647486%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1761896013228%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7086762830598017%
# Le taux de mortalité pour les 75 + ans est de : 3.905038665197422%
# ############
# ################
#  replication = 8
# 0009
# log-configVaccin-configDpt75-Philox-NumRepli9.txt
# Le taux de mort de cas connu est de : 0.7942557677382016%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7934708368757513%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.034145054399279846%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07426961484746475%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.24018110550439895%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4013511805272694%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.156115860213088%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7326620214527928%
# Le taux de mortalité pour les 75 + ans est de : 3.774758791649452%
# ############
# ################
#  replication = 9
# 0010
# log-configVaccin-configDpt75-Philox-NumRepli10.txt
# Le taux de mort de cas connu est de : 0.7972543536290835%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7965187402184237%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04269937697727229%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0772290847951217%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2706324684510293%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4338577241043361%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1238135692524023%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7107889005738512%
# Le taux de mortalité pour les 75 + ans est de : 3.7852802226406466%
# ############
# ################
#  replication = 10
# 0011
# log-configVaccin-configDpt75-Philox-NumRepli11.txt
# Le taux de mort de cas connu est de : 0.8033236771784243%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.802568366550092%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.038120726005336905%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07600159241431725%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2735764545829632%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.41470455791028%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1504959097569416%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7307684381041097%
# Le taux de mortalité pour les 75 + ans est de : 3.817663263021619%
# ############
# ################
#  replication = 11
# 0012
# log-configVaccin-configDpt75-Philox-NumRepli12.txt
# Le taux de mort de cas connu est de : 0.8052960394337135%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.804554121758197%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03426964760677137%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0808960546068492%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2821073943399878%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.42952559650498484%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.150626081346588%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7223563256398386%
# Le taux de mortalité pour les 75 + ans est de : 3.809348009831829%
# ############
# ################
#  replication = 12
# 0013
# log-configVaccin-configDpt75-Philox-NumRepli13.txt
# Le taux de mort de cas connu est de : 0.8026162219628599%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8018756612449391%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.039649683385616495%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07422207244074269%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2507348804631703%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4297282353846908%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.105707553585279%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7775503804320918%
# Le taux de mortalité pour les 75 + ans est de : 3.8278350816702216%
# ############
# ################
#  replication = 13
# 0014
# log-configVaccin-configDpt75-Philox-NumRepli14.txt
# Le taux de mort de cas connu est de : 0.8041676007867409%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8033996129162755%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04052432238657087%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07463315397301169%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.27516265543147966%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.43460526870982713%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1771477171912692%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7270823131463184%
# Le taux de mortalité pour les 75 + ans est de : 3.743566880215552%
# ############
# ################
#  replication = 14
# 0015
# log-configVaccin-configDpt75-Philox-NumRepli15.txt
# Le taux de mort de cas connu est de : 0.8144711461347058%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8136978317862146%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03957614722326767%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08264330188073689%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.26420670816353947%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.40533142423987195%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.152554811485185%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7479319862449672%
# Le taux de mortalité pour les 75 + ans est de : 3.9272840333848293%
# ############
# ################
#  replication = 15
# 0016
# log-configVaccin-configDpt75-Philox-NumRepli16.txt
# Le taux de mort de cas connu est de : 0.8073705264919321%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8065860573199786%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03769083413313024%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07503892393380523%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.27008173329801877%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4269246690193712%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1330874712795072%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.768658041550869%
# Le taux de mortalité pour les 75 + ans est de : 3.823480773159272%
# ############
# ################
#  replication = 16
# 0017
# log-configVaccin-configDpt75-Philox-NumRepli17.txt
# Le taux de mort de cas connu est de : 0.809652406491272%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8088488946501446%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.038408417262837724%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07566914872207688%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.26066006576081086%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4333444178028248%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1514851666575046%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.742782239193549%
# Le taux de mortalité pour les 75 + ans est de : 3.8676616721547847%
# ############
# ################
#  replication = 17
# 0018
# log-configVaccin-configDpt75-Philox-NumRepli18.txt
# Le taux de mort de cas connu est de : 0.795390359728325%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7946715260713496%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03420477778555159%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07043585708363352%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2716149384500485%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.3985764626426424%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1532209832649032%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7049712456889237%
# Le taux de mortalité pour les 75 + ans est de : 3.810610604752779%
# ############
# ################
#  replication = 18
# 0019
# log-configVaccin-configDpt75-Philox-NumRepli19.txt
# Le taux de mort de cas connu est de : 0.7982338919137044%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7974885276456378%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.040748689250495775%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0787813014992564%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2932911967920576%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4281544859868751%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1369751190602568%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7085725844069533%
# Le taux de mortalité pour les 75 + ans est de : 3.7566230325697365%
# ############
# ################
#  replication = 19
# 0020
# log-configVaccin-configDpt75-Philox-NumRepli20.txt
# Le taux de mort de cas connu est de : 0.8144977926143757%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8137440121398914%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03770138173620693%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07958007443550397%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2837805082691626%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.427526996176417%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.169103369293509%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7307049507075092%
# Le taux de mortalité pour les 75 + ans est de : 3.87048807510642%
# ############
# ################
#  replication = 20
# 0021
# log-configVaccin-configDpt75-Philox-NumRepli21.txt
# Le taux de mort de cas connu est de : 0.7983414688262703%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7975808883529915%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.04661914104232629%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07864095588884341%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2683929182983666%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.41292959550396663%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1771171072154751%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7355696647570986%
# Le taux de mortalité pour les 75 + ans est de : 3.7293228681395343%
# ############
# ################
#  replication = 21
# 0022
# log-configVaccin-configDpt75-Philox-NumRepli22.txt
# Le taux de mort de cas connu est de : 0.8075117544498659%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.806770778734686%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03533514021449595%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0766994345926497%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.285968147777587%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4242791280573827%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1460120540231402%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7052806831013196%
# Le taux de mortalité pour les 75 + ans est de : 3.880887143645572%
# ############
# ################
#  replication = 22
# 0023
# log-configVaccin-configDpt75-Philox-NumRepli23.txt
# Le taux de mort de cas connu est de : 0.7895639440015605%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7888066211543887%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.036962679366265135%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07557667414393336%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2578260642776772%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.42093742765137965%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1303601303161046%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.6801293736652168%
# Le taux de mortalité pour les 75 + ans est de : 3.762690941255947%
# ############
# ################
#  replication = 23
# 0024
# log-configVaccin-configDpt75-Philox-NumRepli24.txt
# Le taux de mort de cas connu est de : 0.7980889499856246%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7973499865846072%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.036028636955308994%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07398382810018375%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.28027782120284966%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4229017566688354%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.0960495170325066%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.730744640919984%
# Le taux de mortalité pour les 75 + ans est de : 3.8208219951612983%
# ############
# ################
#  replication = 24
# 0025
# log-configVaccin-configDpt75-Philox-NumRepli25.txt
# Le taux de mort de cas connu est de : 0.8011259767362852%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.8003978899272799%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.03492893901407248%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0684068841469058%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.28642502041897117%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4058651354164483%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1500948947364564%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7805626048787746%
# Le taux de mortalité pour les 75 + ans est de : 3.7473337683714316%
# ############
# ################
#  replication = 25
# 0026
# log-configVaccin-configDpt75-Philox-NumRepli26.txt
# Le taux de mort de cas connu est de : 0.8071949110158093%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.806447516258948%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.040290400812006535%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.07744371213526835%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2491326836052102%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4240953391537004%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1323303247971164%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.7525295946035315%
# Le taux de mortalité pour les 75 + ans est de : 3.872740982171089%
# ############
# ################
#  replication = 26
# 0027
# log-configVaccin-configDpt75-Philox-NumRepli27.txt
# Le taux de mort de cas connu est de : 0.8062354048372276%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.805477728831734%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.0368791683165242%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0848633539123615%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.27173204015222957%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.41519901219712685%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.1395478485395303%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.709013226671515%
# Le taux de mortalité pour les 75 + ans est de : 3.881279649677655%
# ############
# ################
#  replication = 27
# 0028
# log-configVaccin-configDpt75-Philox-NumRepli28.txt
# Le taux de mort de cas connu est de : 0.7971245275378905%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7963801991573932%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.037677365225734026%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.0841798080700376%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2653447807463148%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4403587381057562%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.130869849095084%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.6845910677880767%
# Le taux de mortalité pour les 75 + ans est de : 3.8023221254805275%
# ############
# ################
#  replication = 28
# 0029
# log-configVaccin-configDpt75-Philox-NumRepli29.txt
# Le taux de mort de cas connu est de : 0.7966722351290161%
# Le taux de mortalité du département sur l'ensemble de la population est de : 0.7959183956206248%
# Le taux de mortalité pour les 0 - 15 ans est de : 0.0%
# Le taux de mortalité pour les 15 - 25 ans est de : 0.035761903466183624%
# Le taux de mortalité pour les 25 - 35 ans est de : 0.08099373701894932%
# Le taux de mortalité pour les 35 - 45 ans est de : 0.2573992971880059%
# Le taux de mortalité pour les 45 - 55 ans est de : 0.4296527003233794%
# Le taux de mortalité pour les 55 - 65 ans est de : 1.146450927562974%
# Le taux de mortalité pour les 65 - 75 ans est de : 1.663414795462813%
# Le taux de mortalité pour les 75 + ans est de : 3.8242856449813227%
# ############
# ################
#  replication = 29
#                            Champs            R1            R2            R3  \
# 0            nbCasCovidConnuTotal  2.163368e+06  2.163449e+06  2.163403e+06
# 1              tauxDeMortCasConnu  8.041165e-01  8.043638e-01  8.058600e-01
# 2   tauxMortalitePopulationGobale  8.033534e-01  8.036305e-01  8.051083e-01
# 3               tauxDeMort0-15ans  0.000000e+00  0.000000e+00  0.000000e+00
# 4              tauxDeMort15-25ans  4.111093e-02  4.201713e-02  3.880120e-02
# 5              tauxDeMort25-35ans  7.770915e-02  7.483223e-02  7.408123e-02
# 6              tauxDeMort35-45ans  2.629086e-01  2.705896e-01  2.729785e-01
# 7              tauxDeMort45-55ans  4.315350e-01  4.397513e-01  4.219513e-01
# 8              tauxDeMort55-65ans  1.143572e+00  1.161350e+00  1.152687e+00
# 9              tauxDeMort65-75ans  1.743095e+00  1.711430e+00  1.697064e+00
# 10               tauxDeMort75+ans  3.810423e+00  3.807177e+00  3.871902e+00
# 11                 nbRandomGenere  0.000000e+00  0.000000e+00  0.000000e+00
#
#               R4            R5            R6            R7            R8  \
# 0   2.163440e+06  2.163451e+06  2.163393e+06  2.163373e+06  2.163419e+06
# 1   7.963244e-01  8.100946e-01  8.047544e-01  8.124813e-01  8.176410e-01
# 2   7.955951e-01  8.093569e-01  8.040000e-01  8.117121e-01  8.168843e-01
# 3   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 4   4.105122e-02  3.875819e-02  3.347919e-02  3.769787e-02  3.223051e-02
# 5   7.340053e-02  6.854367e-02  6.639492e-02  8.181796e-02  7.632361e-02
# 6   2.688011e-01  2.745617e-01  2.642195e-01  2.835898e-01  2.641105e-01
# 7   4.069479e-01  4.309164e-01  4.033869e-01  4.177276e-01  4.246455e-01
# 8   1.150485e+00  1.211498e+00  1.124204e+00  1.161164e+00  1.192107e+00
# 9   1.728450e+00  1.738314e+00  1.749229e+00  1.766011e+00  1.748855e+00
# 10  3.772004e+00  3.790733e+00  3.892874e+00  3.836936e+00  3.887594e+00
# 11  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#               R9  ...           R24           R25           R26           R27  \
# 0   2.163470e+06  ...  2.163346e+06  2.163418e+06  2.163455e+06  2.163418e+06
# 1   8.125835e-01  ...  7.895639e-01  7.980889e-01  8.011260e-01  8.071949e-01
# 2   8.118506e-01  ...  7.888066e-01  7.973500e-01  8.003979e-01  8.064475e-01
# 3   0.000000e+00  ...  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 4   3.372603e-02  ...  3.696268e-02  3.602864e-02  3.492894e-02  4.029040e-02
# 5   8.540501e-02  ...  7.557667e-02  7.398383e-02  6.840688e-02  7.744371e-02
# 6   2.753112e-01  ...  2.578261e-01  2.802778e-01  2.864250e-01  2.491327e-01
# 7   4.216289e-01  ...  4.209374e-01  4.229018e-01  4.058651e-01  4.240953e-01
# 8   1.176190e+00  ...  1.130360e+00  1.096050e+00  1.150095e+00  1.132330e+00
# 9   1.708676e+00  ...  1.680129e+00  1.730745e+00  1.780563e+00  1.752530e+00
# 10  3.905039e+00  ...  3.762691e+00  3.820822e+00  3.747334e+00  3.872741e+00
# 11  0.000000e+00  ...  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#              R28           R29           R30       Moyenne     Variance  \
# 0   2.163388e+06  2.163401e+06  2.163374e+06  2.163397e+06  2409.550575
# 1   8.062354e-01  7.971245e-01  7.966722e-01  8.038869e-01     0.000047
# 2   8.054777e-01  7.963802e-01  7.959184e-01  8.031348e-01     0.000047
# 3   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00     0.000000
# 4   3.687917e-02  3.767737e-02  3.576190e-02  3.790316e-02     0.000010
# 5   8.486335e-02  8.417981e-02  8.099374e-02  7.662323e-02     0.000022
# 6   2.717320e-01  2.653448e-01  2.573993e-01  2.698533e-01     0.000140
# 7   4.151990e-01  4.403587e-01  4.296527e-01  4.219447e-01     0.000132
# 8   1.139548e+00  1.130870e+00  1.146451e+00  1.149414e+00     0.000562
# 9   1.709013e+00  1.684591e+00  1.663415e+00  1.727926e+00     0.000790
# 10  3.881280e+00  3.802322e+00  3.824286e+00  3.823699e+00     0.002765
# 11  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00     0.000000
#
#                                    Intervalle95%
# 0       (2163378.7038816167, 2163415.3627850497)
# 1       (0.8013310195410027, 0.8064428720350406)
# 2        (0.8005806173154723, 0.805689073794917)
# 3                                     (nan, nan)
# 4   (0.036701541750113566, 0.039104770736130494)
# 5     (0.07486171059256654, 0.07838474811656777)
# 6       (0.265432546679122, 0.27427407729596787)
# 7      (0.41765728635830673, 0.4262320889356093)
# 8       (1.1405591830024717, 1.1582691026473564)
# 9        (1.7174286346426548, 1.738424024945171)
# 10       (3.804064339027248, 3.8433334927207183)
# 11                                    (nan, nan)
#
# [12 rows x 34 columns]
# /tmp/ipykernel_132162/4102628540.py:362: DeprecationWarning: Use of keyword argument 'alpha' for method 'interval' is deprecated and wil be removed in SciPy 1.11.0. Use first positional argument or keyword argument 'confidence' instead.
#   listIntervalle95 = [st.t.interval(alpha=0.95, df=len(r)-1, loc=np.mean(r), scale=st.sem(r)) for r in zip(*listResReplicationTruncated)]
# /usr/lib/python3/dist-packages/scipy/stats/_distn_infrastructure.py:2351: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /usr/lib/python3/dist-packages/scipy/stats/_distn_infrastructure.py:2352: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
import matplotlib.pyplot as plt
plt.plot([44,221,588,917,1990],[70000,161000,264000,330000,492000])

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

x = np.array([44,221,588,917,1990]).reshape(-1,1)
y = np.array([70000,161000,264000,330000,492000])

model = LinearRegression()
model.fit(np.log(x),y)

x_pred = np.array([50,100,220,500,1000,1500,3000,5000,8000,12000]).reshape(-1,1)
y_pred = model.predict(np.log(x_pred))
print(y_pred)

plt.plot([44,221,588,917,1990],[70000,161000,264000,330000,492000],color='r')
plt.plot([50,100,220,500,1000,1500,3000,5000,8000,12000],y_pred)
# Out:
# [ 43885.06248518 116924.96278337 200008.1067469  286518.35933351
#  359558.2596317  402283.86236256 475323.76266075 529151.65618184
#  578677.96052628 621403.56325713]
